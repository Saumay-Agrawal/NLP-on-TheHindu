# %% [markdown]
# # Performing NER and Sentimental Analysis on Sports articles of The Hindu

# %%
# Import necessary packages
import nltk
from nltk.tokenize import word_tokenize, regexp_tokenize, sent_tokenize
from nltk.tag import pos_tag
from nltk.chunk import conlltags2tree, tree2conlltags
from nltk.text import TextCollection
from nltk.sentiment.vader import SentimentIntensityAnalyzer
from nltk.corpus import stopwords

import spacy
from spacy import displacy
from collections import Counter
nlp = spacy.load("en_core_web_sm")

from matplotlib import pyplot as plt
import seaborn as sb
# %matplotlib inline
import pandas as pd
import numpy as np

from pprint import pprint
from pymongo import MongoClient

# %% [markdown]
# ## Fetching the articles belonging to relevant collection

# %%
# fetch the article collection
client = MongoClient()
db = client["TheHindu"]
col = db['sport']
article = []
for item in col.find():
    article.append(item['content'])
print('Number of articles found:', len(article))
# Out:
# Number of articles found: 49

# %%
# Basic exploration
corpus = ' '.join(article)
stoplist = stopwords.words('english')
tokens = [token for token in regexp_tokenize(corpus, '\w+') if len(token) > 1 and not token.isdigit() and token.lower() not in stoplist]
freqdist = nltk.FreqDist(tokens)
print('Total number of tokens found:', len(freqdist))
# Out:
# Total number of tokens found: 3543

# %%
sb.set(rc={'figure.figsize':(11.7,8.27)})
freqdist.plot(30)

# %% [markdown]
# ## Demonstrating NER on a single article using Spacy

# %%
# perform ner on each article
print(article[0])
# Out:
# Siddharth Desai... unstoppable. Special Arrangement Raider Siddharth Desai has moved up the ranks, in terms of value at the Pro- Kabaddi League Season-7 player auction. In only his second season as pro, the Kolhapur-born player (base price ₹30 lakh) was picked up by Telugu Titans for a staggering ₹1.45 crore on Monday. Last season’s highest earner, Monu Goyat (₹1.51 crore) moved to UP Yoddhas for ₹93 lakh. Puneri Paltan and Tamil Thalaivas were involved in a frenetic three-way bid for the former U Mumba sensation, Desai. Named the ‘Best debutant’ last season for his power-packed raiding and speed, Desai will team up with Iranian coach Gholamreza Mazandarani again.  Titans convinced the only foreign head coach in PKL to switch from U Mumba and bid successfully for the 28-year-old player, a crowd-puller in his own right. Thalaivas came close at ₹1.44 crore before Titans sealed the deal. U Mumba did not execute the Final Bid Match card. Each of the 12 teams is allotted a purse of ₹4.4 crore to recruit a minimum of 18 and maximum 25 players. Paltan, meanwhile, used the Final Bid Match card to retain reputed raider Nitin Tomar for ₹1.2 crore, the second highest bid. Tomar represented Pune last season, so the team held the right to match the highest bid by any other franchise for a former player released into the pool. Thalaivas got Rahul Chaudhari for ₹94 lakh in a straight bid. Nineteen domestic players went under the hammer. Iranian Esmaeil Nabibaksh, taken by Bengal Warriors for ₹77.75 lakh, became the second-highest paid foreigner (Fazel Atrachali at ₹1 crore last season is the topper). Several team managements used the Final Bid Match card to retain stars released earlier into the pool. Others returning to last season’s squads were Ravinder Pahal (Dabang Delhi), Girish Ernak (Paltan), Jaideep (Patna Pirates), Mahender Singh (Bengaluru Bulls), Parvesh Bainswal (Gujarat Fortunegiants), Vishal Bharadwaj (Titans), Chandran Ranjith (Dabang), Nitin Tomar (Paltan), Rishank Devadiga (UP Yodhas) and Shrikant Jadhav (Yodhas). Last season, five domestic players earned upwards of ₹1 crore, a season later only two have made the crorepati club.

# %%
displacy.render(nlp(article[0]), jupyter=True, style='ent')
# Out:
# <div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Siddharth Desai
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
# ... unstoppable. Special Arrangement Raider
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Siddharth Desai
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  has moved up the ranks, in terms of value at the Pro-
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Kabaddi League
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  Season-7 player auction. In
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     only his second season
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  as pro, the
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Kolhapur
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# -born player (base price ₹30 lakh) was picked up by
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Telugu Titans
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
#  for a staggering ₹1.45 crore on
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Monday
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# .
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Last season’s
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  highest earner,
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Monu Goyat
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  (₹1.51 crore) moved to UP Yoddhas for ₹93 lakh.
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Puneri Paltan
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  and
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Tamil Thalaivas
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  were involved in a frenetic
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     three
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
# -way bid for the former U Mumba sensation,
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Desai
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# . Named the ‘Best debutant’ last season for his power-packed raiding and speed,
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Desai
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  will team up with
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Iranian
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
#  coach
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Gholamreza Mazandarani
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  again.
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Titans
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
#  convinced the only foreign head coach in
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     PKL
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  to switch from
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     U Mumba
#     <span style

# %% [markdown]
# ## Perfroming NER to find Named Entities in a corpus. Results are narrowed down to Persons, Organizations and GeoPolitical Entities only.

# %%
def getNE(text):
    ne = {}
    for x in nlp(text).ents:
        entity, label = x.text.strip(), x.label_
        if(label in ['GPE', 'PERSON', 'ORG'] and len(entity) > 1 and entity.lower() not in stoplist):
            ne[entity] = label
    return ne

# %%
getNE(corpus)
# Out:
# {'Siddharth Desai': 'PERSON',
#  'Kabaddi League': 'ORG',
#  'Kolhapur': 'ORG',
#  'Monu Goyat': 'PERSON',
#  'Puneri Paltan': 'ORG',
#  'Tamil Thalaivas': 'PERSON',
#  'Desai': 'ORG',
#  'Gholamreza Mazandarani': 'PERSON',
#  'PKL': 'ORG',
#  'U Mumba': 'ORG',
#  'Final Bid Match': 'ORG',
#  'Paltan': 'GPE',
#  'Nitin Tomar': 'PERSON',
#  'Tomar': 'PERSON',
#  'Pune': 'GPE',
#  'Rahul Chaudhari': 'PERSON',
#  'Esmaeil Nabibaksh': 'PERSON',
#  'Bengal Warriors': 'PERSON',
#  'Fazel Atrachali': 'PERSON',
#  'Ravinder Pahal (Dabang Delhi': 'ORG',
#  'Girish Ernak': 'ORG',
#  'Jaideep': 'PERSON',
#  'Mahender Singh': 'PERSON',
#  'Bengaluru Bulls': 'PERSON',
#  'Parvesh Bainswal (Gujarat Fortunegiants': 'ORG',
#  'Vishal Bharadwaj': 'PERSON',
#  'Chandran Ranjith': 'PERSON',
#  'Dabang': 'GPE',
#  'Rishank Devadiga': 'ORG',
#  'UP Yodhas': 'ORG',
#  'Shrikant Jadhav': 'PERSON',
#  'Yodhas': 'ORG',
#  'Rahul Dravid': 'PERSON',
#  'Barcelona': 'GPE',
#  'Josep Maria Bartomeu': 'PERSON',
#  'Jordi Mestre': 'PERSON',
#  'India': 'GPE',
#  'Lionel Messi': 'PERSON',
#  'Dravid': 'PERSON',
#  'Spain': 'GPE',
#  'Camp Nou': 'PERSON',
#  'Lionel': 'PERSON',
#  'Messi': 'PERSON',
#  'Luis': 'PERSON',
#  'Suarez': 'PERSON',
#  'Ric Charlesworth': 'PERSON',
#  'Graham Reid’s': 'PERSON',
#  'Hockey India': 'GPE',
#  'Reid’s': 'ORG',
#  'the Sports Ministry': 'ORG',
#  'Reid': 'PERSON',
#  'Australia': 'GPE',
#  'Graham Reid': 'PERSON',
#  '’s': 'PERSON',
#  'Charlesworth': 'PERSON',
#  'National': 'ORG',
#  'Harendra Singh': 'PERSON',
#  'Harendra': 'GPE',
#  'Jamie Dwyer': 'PERSON',
#  'Aussie': 'ORG',
#  'Rio': 'ORG',
#  'John Reid': 'PERSON',
#  'the Netherlands': 'GPE',
#  'Bengaluru': 'GPE',
#  'HI': 'ORG',
#  'the Sports Authority of India': 'ORG',
#  'SAI': 'ORG',
#  'Charlesworth’s': 'ORG',
#  'Netherlands': 'GPE',
#  'Mohd': 'PERSON',
#  'Mushtaque Ahmad': 'PERSON',
#  'Olympic': 'ORG',
#  'Max Caldas': 'PERSON',
#  'Amsterdam': 'GPE',
#  'David Warner': 'PERSON',
#  'Punjab': 'GPE',
#  'R. Ashwin': 'PERSON',
#  'Mohali': 'GPE',
#  'KXIP': 'ORG',
#  'Ankit Rajpoot': 'GPE',
#  'Andrew Tye': 'PERSON',
#  'M. Ashwin': 'PERSON',
#  'Bhuvneshwar Kumar': 'PERSON',
#  'Bayern Munich': 'ORG',
#  'Bundesliga': 'GPE',
#  'Jetfire': 'PERSON',
#  'S. Amit': 'PERSON',
#  'Golden Steal (Rupesh)': 'ORG',
#  'Master Of Studies (Rathod': 'ORG',
#  'Makati': 'GPE',
#  'Ayyar': 'PERSON',
#  'Tasman': 'PERSON',
#  'S.J. Sunil': 'PERSON',
#  'Allauddin Khilji': 'PERSON',
#  'Rising Brave': 'PERSON',
#  'Pair': 'ORG',
#  'Grey Falcon (Kaviraj': 'ORG',
#  'Strong Values': 'PERSON',
#  'Jack Flash': 'PERSON',
#  'Nazil': 'ORG',
#  'Parmar': 'ORG',
#  'Gold Eclipse': 'PERSON',
#  'Pranil': 'ORG',
#  'Golden Era (Baria': 'ORG',
#  'N. Rawal': 'PERSON',
#  'CSK': 'ORG',
#  'M.S. Dhoni': 'PERSON',
#  'Imran Tahir': 'PERSON',
#  'Harbhajan Singh': 'PERSON',
#  'KKR': 'ORG',
#  'R. Ragu': 'PERSON',
#  'Chennai Super Kings': 'ORG',
#  'Kolkata Knight Riders': 'PERSON',
#  'Andre Russell’s': 'PERSON',
#  'Rajasthan Royals': 'ORG',
#  'Kings XI Punjab': 'PERSON',
#  'Russell': 'PERSON',
#  'Stephen Fleming': 'PERSON',
#  'Chris': 'PERSON',
#  'Lynn': 'PERSON',
#  'Dinesh': 'PERSON',
#  'Karthik': 'PERSON',
#  'Robin': 'PERSON',
#  'Fleming': 'ORG',
#  'Suresh Raina': 'PERSON',
#  'MS Dhoni': 'PERSON',
#  '& WK': 'ORG',
#  'Ambati Rayudu': 'PERSON',
#  'Shane Watson': 'PERSON',
#  'Faf du Plessis': 'ORG',
#  'Murali Vijay': 'PERSON',
#  'Kedar Jadhav': 'PERSON',
#  'Sam Billings': 'PERSON',
#  'Ravindra Jadeja': 'PERSON',
#  'Dhruv Shorey': 'PERSON',
#  'Chaitanya': 'GPE',
#  'Rituraj Gaikwad': 'PERSON',
#  'Dwayne Bravo': 'PERSON',
#  'Karn Sharma': 'PERSON',
#  'Mitchell Santner': 'PERSON',
#  'Shardul Thakur': 'PERSON',
#  'Mohit Sharma': 'PERSON',
#  'K M Asif': 'ORG',
#  'Deepak Chahar': 'PERSON',
#  'N Jagadeesan': 'ORG',
#  'Scott Kuggeleign': 'PERSON',
#  'Captain & WK': 'ORG',
#  'Robin Uthappa': 'ORG',
#  'Chris Lynn': 'PERSON',
#  'Shubman Gill': 'PERSON',
#  'Andre Russell': 'PERSON',
#  'Carlos Brathwaite': 'PERSON',
#  'Sunil Narine': 'PERSON',
#  'Piyush Chawla': 'ORG',
#  'Kuldeep Yadav': 'PERSON',
#  'Nitish Rana': 'ORG',
#  'Nikhil Naik': 'PERSON',
#  'Joe Denly': 'PERSON',
#  'Mundhe': 'PERSON',
#  'Sandeep Warrier': 'PERSON',
#  'Prasidh Krishna': 'PERSON',
#  'Lockie Ferguson': 'PERSON',
#  'Harry Gurney': 'PERSON',
#  'K C Cariappa': 'ORG',
#  'Yarra Prithviraj': 'PERSON',
#  'Delhi Capitals': 'ORG',
#  'Sourav Ganguly': 'PERSON',
#  'Ricky Ponting': 'PERSON',
#  'Mohammad Kaif': 'PERSON',
#  'File\n\xa0 | Photo Credit': 'ORG',
#  'CAB': 'ORG',
#  'BCCI': 'ORG',
#  'DK Jain': 'PERSON',
#  'Ombudsman': 'ORG',
#  'Ganguly': 'PERSON',
#  'IPL': 'ORG',
#  'PTI': 'ORG',
#  'Jain': 'PERSON',
#  'the Delhi Capitals': 'ORG',
#  'Indian Premiere League': 'ORG',
#  'the Apex Council of the BCCI': 'ORG',
#  'the Cricket Committees': 'ORG',
#  'the BCCI Technical Committee': 'ORG',
#  'the IPL Technical Committee': 'ORG',
#  'the IPL Governing Council': 'ORG',
#  'Red Chillies Entertainment Private Limited': 'ORG',
#  'West Bengal': 'GPE',
#  'Abhijeet Mukherjee': 'PERSON',
#  'Bhaswati Shantua': 'PERSON',
#  'Justice': 'ORG',
#  'D K Jain': 'PERSON',
#  'Kolkata Knight Riders and Delhi Capitals': 'ORG',
#  'Kolkata': 'GPE',
#  'AP India’s': 'ORG',
#  'UK': 'GPE',
#  'Mumbai': 'GPE',
#  'The Committee of Administrators': 'ORG',
#  'CoA': 'PERSON',
#  'United Kingdom': 'GPE',
#  'Cricket Australia': 'ORG',
#  'Uppal': 'GPE',
#  'Hyderabad': 'GPE',
#  'Premier League’s': 'ORG',
#  'The Tamil Nadu Cricket Association': 'ORG',
#  'TNCA': 'ORG',
#  'Bangalore': 'PERSON',
#  'Committee of Administrators': 'ORG',
#  'Players’ Association': 'ORG',
#  'The Players’ Association': 'ORG',
#  'PayTm': 'GPE',
#  'Women’s IPL': 'ORG',
#  'Visakhapatnam': 'GPE',
#  'Knight Riders’': 'ORG',
#  'Royals': 'ORG',
#  'Dinesh Karthik’s': 'PERSON',
#  'Rahane': 'PERSON',
#  'Karnataka': 'PERSON',
#  'Steve Smith': 'PERSON',
#  'Jos Buttler': 'PERSON',
#  '’s IPL': 'ORG',
#  'Buttler': 'PERSON',
#  'Smith': 'ORG',
#  'Rahul Tripathi': 'PERSON',
#  'Gurney': 'ORG',
#  'Chawla': 'ORG',
#  'Suni Narine': 'PERSON',
#  'Shreyas Gopal': 'PERSON',
#  'Narine': 'PERSON',
#  'Dhawal Kulkarni': 'PERSON',
#  'Sushree Dibyadarshini': 'PERSON',
#  'the India Red': 'ORG',
#  'India Green': 'PERSON',
#  'India Blue': 'ORG',
#  'the U-23 Women’s One-': 'ORG',
#  'Day Challenger': 'PERSON',
#  'Ranchi': 'GPE',
#  'R. Kalpana': 'PERSON',
#  'S. Meghana': 'PERSON',
#  'Ridhima Aggarwal': 'PERSON',
#  'Ruzu Saha': 'PERSON',
#  'Tejal Hasabnis': 'GPE',
#  'C.H. Jhansilakshmi': 'PERSON',
#  'Renuka Chaudhary,': 'PERSON',
#  'Arundhati Reddy': 'PERSON',
#  'Shanti Kumari': 'PERSON',
#  'Devyani Prasad': 'PERSON',
#  'Suman Meena': 'PERSON',
#  'Shivali Shinde': 'PERSON',
#  'Priya Punia': 'ORG',
#  'Yastika Bhatia': 'ORG',
#  'Ayushi Garg': 'PERSON',
#  'I.V. Drishya': 'PERSON',
#  'Ekta Singh': 'PERSON',
#  'Radha Yadav': 'PERSON',
#  'Rashi Kanojia': 'PERSON',
#  'Manali Dakshini': 'PERSON',
#  'Renuka Singh': 'PERSON',
#  'A. Akshaya': 'PERSON',
#  'S. Anusha': 'PERSON',
#  'India Blue: Devika': 'ORG',
#  'Nuzhat Parween': 'PERSON',
#  'Shefali Verma': 'PERSON',
#  'Simran': 'GPE',
#  'Tanushre Sarkar': 'PERSON',
#  'Prativa Rana': 'PERSON',
#  'Minnu Mani': 'GPE',
#  'Tanuja Kanwar': 'PERSON',
#  'C. Pratyusha': 'PERSON',
#  'Simran Dil Bahadur': 'PERSON',
#  'Kshama Singh': 'PERSON',
#  'Vrushali Bhagat': 'PERSON',
#  'Indrani Roy': 'PERSON',
#  'G. Sathiyan': 'PERSON',
#  'Chun Ting Wong': 'PERSON',
#  'Hong Kong': 'GPE',
#  'Lin Yun-Ju': 'PERSON',
#  'Taipei': 'GPE',
#  'Lin': 'PERSON',
#  'Amir': 'PERSON',
#  'Mohammad Amir’s': 'PERSON',
#  'Sarfaraz Ahmed': 'PERSON',
#  'Pakistan': 'GPE',
#  'England': 'GPE',
#  'Mickey Arthur': 'PERSON',
#  'Azhar Mahmood': 'ORG',
#  'Arthur': 'ORG',
#  'ODI': 'ORG',
#  'UAE': 'GPE',
#  'Jennifer Kupcho': 'PERSON',
#  'Augusta National': 'ORG',
#  'Kevin C. Cox': 'PERSON',
#  'Augusta National Golf Club': 'ORG',
#  'Mexico': 'GPE',
#  'Maria Fassi': 'PERSON',
#  'Masters': 'ORG',
#  'US': 'GPE',
#  'Kupcho': 'PERSON',
#  'Fassi': 'PERSON',
#  'Yuka Yasuda': 'PERSON',
#  'Yuka Saso': 'PERSON',
#  'Philippines': 'GPE',
#  'Golfer-of': 'GPE',
#  'Augusta': 'PERSON',
#  'Butler Cabin': 'ORG',
#  'Fred Ridley': 'PERSON',
#  'Georgia': 'GPE',
#  'Rory McIlroy': 'PERSON',
#  'Career': 'ORG',
#  'Golf': 'PERSON',
#  'Jack Nicklaus': 'PERSON',
#  'Augusta National GC & @TheMasters': 'ORG',
#  'Inaugural @anwagolf': 'PERSON',
#  'Harjeet Singh': 'PERSON',
#  'the Sports Authority of India Centre': 'ORG',
#  'Lucknow': 'GPE',
#  'Santa Singh': 'GPE',
#  'Dipsan Tirkey': 'PERSON',
#  'Manpreet': 'PERSON',
#  'Armaan Qureshi': 'PERSON',
#  'David John': 'PERSON',
#  'ProKabaddi League': 'ORG',
#  'Sanjeev Kumar Baliyan': 'PERSON',
#  'Gholamreza': 'ORG',
#  'Jakarta': 'GPE',
#  'Iran': 'GPE',
#  'B.C. Ramesh (Bengal Warriors': 'ORG',
#  'Randhir Singh': 'PERSON',
#  'Krishan Kumar Hooda': 'PERSON',
#  'Manpreet Singh': 'PERSON',
#  'Gujarat Fortunegiants': 'ORG',
#  'Srinivas Reddy': 'PERSON',
#  'Jaipur Pink Panthers': 'PERSON',
#  'Ram Meher Singh': 'PERSON',
#  'Patna Pirates': 'GPE',
#  'Anup Kumar': 'PERSON',
#  'Sanjeev Kumar': 'PERSON',
#  'Bhaskaraan (Tamil Thalaivas': 'ORG',
#  'Jasveer Singh': 'PERSON',
#  'Yoddha': 'PERSON',
#  'Rakesh Kumar': 'PERSON',
#  'Haryana Steelers': 'PERSON',
#  'Anup': 'PERSON',
#  'Ashok Shinde': 'PERSON',
#  'Air India': 'ORG',
#  'Shinde': 'PERSON',
#  'Shubham Shinde': 'PERSON',
#  'Amit Singh': 'PERSON',
#  'Sandeep': 'PERSON',
#  'Rajesh Mondal': 'PERSON',
#  'Sandeep Narwal': 'PERSON',
#  'Vivek Bendre Retained': 'ORG',
#  'the ProKabaddi League': 'ORG',
#  'U Mumba and Tamil Thalaivas': 'ORG',
#  'FBM': 'ORG',
#  'Young Players': 'ORG',
#  'Retained Young Players': 'ORG',
#  'PKL’s': 'ORG',
#  'Naveen Kumar': 'PERSON',
#  'Dabang Delhi': 'GPE',
#  'Pawan Kumar': 'PERSON',
#  'Nitesh Kumar': 'PERSON',
#  'Delhi': 'PERSON',
#  'Yoddhas': 'PERSON',
#  'Naveen': 'GPE',
#  'Sachin Talwar': 'PERSON',
#  'Retained Elite Players:': 'ORG',
#  'Rohit Kumar': 'PERSON',
#  'Pawan Kumar Sehrawat': 'PERSON',
#  'Kumar': 'PERSON',
#  'Sunil Kumar': 'PERSON',
#  'Bengal Warriors:': 'ORG',
#  'Baldev Singh': 'PERSON',
#  'Maninder Singh': 'PERSON',
#  'Joginder Narwal': 'PERSON',
#  'Kuldeep Singh': 'PERSON',
#  'Vikash Chandola': 'PERSON',
#  'Deepak Hooda': 'PERSON',
#  'Sandeep Kumar Dhoull': 'PERSON',
#  'Pardeep Narwal': 'PERSON',
#  'Vikas Jaglan': 'PERSON',
#  'Tushar Patil': 'PERSON',
#  'Jawahar': 'PERSON',
#  'Ajay Thakur': 'PERSON',
#  'Manjeet Chillar': 'PERSON',
#  'Victor Onyango': 'PERSON',
#  'Armaan': 'ORG',
#  'Mohsen': 'PERSON',
#  'Farhad Milaghardan': 'PERSON',
#  'Nitin Madane': 'PERSON',
#  'Rajguru Subramaniam': 'PERSON',
#  'Arjun Deshwal': 'PERSON',
#  'Amit': 'PERSON',
#  'Sachin Kumar': 'PERSON',
#  'the Committee of Administrators': 'ORG',
#  'C.K. Khanna': 'PERSON',
#  'Amitabh Choudhary': 'PERSON',
#  'Anirudh Chaudhry': 'ORG',
#  'Chennai': 'GPE',
#  'Virat Kohli': 'PERSON',
#  'the Indian Premier League': 'ORG',
#  'Royal Challengers Bangalore': 'ORG',
#  'RCB': 'ORG',
#  'RR': 'ORG',
#  'Sawai Man Singh': 'ORG',
#  'Moeen Ali': 'PERSON',
#  'Moeen': 'ORG',
#  'Kagiso Rabada': 'PERSON',
#  'Royal Challengers Bangalore’s': 'ORG',
#  'Skipper Shreyas Iyer': 'PERSON',
#  'Capitals': 'ORG',
#  'Rishab Pant': 'PERSON',
#  'Tim Southee': 'PERSON',
#  'Shikhar Dhawan': 'PERSON',
#  'Navdeep Saini': 'PERSON',
#  'Kiwi': 'ORG',
#  'Shreyas': 'ORG',
#  'Parthiv Patel': 'PERSON',
#  'Southee': 'ORG',
#  'Prithvi Shaw': 'PERSON',
#  'Shaw': 'PERSON',
#  'Colin Ingram': 'PERSON',
#  'Kohli': 'ORG',
#  'Sandeep Lamichhane': 'PERSON',
#  'A.B. de Villiers': 'ORG',
#  'Marcus Stoinis': 'PERSON',
#  'RCB de Villiers': 'ORG',
#  'Chris Morris': 'PERSON',
#  'Ishant Sharma': 'ORG',
#  'Ali': 'PERSON',
#  'Ishant': 'ORG',
#  'Lamichhane': 'PERSON',
#  'Rabada': 'GPE',
#  'Arms': 'PERSON',
#  'P. Trevor': 'ORG',
#  'Harisinghji Trophy': 'PERSON',
#  'K.N. Dhunjibhoy': 'PERSON',
#  'Z.K. Dhunjibhoy': 'PERSON',
#  'Vispi R. Patel': 'PERSON',
#  'S.S. Attaollahi': 'PERSON',
#  'S.K. Sunderji': 'PERSON',
#  'Jockey A. Sandesh': 'PERSON',
#  'M.D. PETIT PLATE': 'ORG',
#  'Brazos (Pranil': 'ORG',
#  'Tanala': 'GPE',
#  'K.H. Vaccha': 'PERSON',
#  'DIEGO RIVERA PLATE': 'ORG',
#  'Maiden': 'PERSON',
#  'GOLDMINE': 'PERSON',
#  'Wizard Of Stocks': 'PERSON',
#  'Istanbul': 'GPE',
#  'Ramon': 'PERSON',
#  '₹16': 'GPE',
#  'Goldmine': 'PERSON',
#  'Mukul Sonawala': 'PERSON',
#  'D.R. Thacker': 'PERSON',
#  'DT Racing & Breeders LLP': 'ORG',
#  'M/s': 'ORG',
#  'Ajay K. Arora &': 'ORG',
#  'Zervan': 'GPE',
#  'Turning Point (Dashrath': 'ORG',
#  '₹10': 'PERSON',
#  'Five Stars Shipping': 'ORG',
#  'Pvt.': 'ORG',
#  'Peter': 'PERSON',
#  'Epiphany': 'PERSON',
#  'El Comandante': 'ORG',
#  'Cyrus S. Poonawalla': 'PERSON',
#  'Adar C. Poonawalla &': 'PERSON',
#  'Natasha A. Poonawalla': 'PERSON',
#  'Poonawalla Racing &': 'ORG',
#  'Saleem Fazelbhoy': 'PERSON',
#  'Dinsha P. Shroff &': 'ORG',
#  'Munchi P. Shroff': 'PERSON',
#  'Altaf Hussain': 'PERSON',
#  'KAZAKH PLATE': 'ORG',
#  'Mario': 'PERSON',
#  'Ustad Pedro (': 'ORG',
#  'Philadelphia': 'GPE',
#  'Geoffrey B. Nagpal & Nishant G. Nagpal': 'ORG',
#  'BEJAN BHARUCHA PLATE': 'ORG',
#  'Trevor': 'ORG',
#  'Cracklin Rosie': 'PERSON',
#  'Nose': 'PERSON',
#  '₹23': 'ORG',
#  'Champaklal Zaveri': 'PERSON',
#  'Bindu C. Zaveri': 'PERSON',
#  'Desai &': 'ORG',
#  'Harsha N Desai': 'PERSON',
#  'Zaveri Stud Farm Pvt Ltd.': 'ORG',
#  'S.S. Shah': 'PERSON',
#  'Dinesh Karthik': 'PERSON',
#  'Jaipur': 'GPE',
#  'Knight Riders': 'ORG',
#  'S. Midhun': 'PERSON',
#  'Prashant Chopra': 'ORG',
#  'Stuart Binny': 'GPE',
#  'Varun Aaron': 'PERSON',
#  'Arie Irawan': 'PERSON',
#  'Getty Images': 'PERSON',
#  'Hainan': 'GPE',
#  'PGA': 'ORG',
#  'Arie': 'PERSON',
#  'the China Golf Association': 'ORG',
#  'Ahmad': 'PERSON',
#  'Jeny': 'PERSON',
#  'Sluman': 'PERSON',
#  'Tour': 'PERSON',
#  'Marina Malek': 'PERSON',
#  'Malaysia': 'GPE',
#  'The Star': 'ORG',
#  'Agrami': 'PERSON',
#  'Joplin': 'PERSON',
#  'Chouhan': 'ORG',
#  'Furiosa': 'PERSON',
#  'Nilesh': 'PERSON',
#  'Dumas': 'PERSON',
#  'Conscience': 'PERSON',
#  '800/50': 'ORG',
#  'Gallantry (Kamble': 'ORG',
#  'Super Sunshine': 'PERSON',
#  'Niccolini': 'PERSON',
#  'Akina Speed Star': 'PERSON',
#  '800/54': 'ORG',
#  'Sachertorte': 'PERSON',
#  'Auspicious': 'PERSON',
#  'Kunal': 'ORG',
#  '600/40': 'ORG',
#  'Minstrel Heights': 'PERSON',
#  'Jaykumar': 'PERSON',
#  'Regal Shot (Bhawani': 'ORG',
#  'Steppenwolf': 'ORG',
#  'Arrowhead': 'PERSON',
#  'Trio': 'ORG',
#  'B.Nikhil': 'PERSON',
#  'Caesar (Chouhan': 'ORG',
#  'Divine Power (S.J.Sunil': 'ORG',
#  'Silver Flames (Sandesh': 'ORG',
#  'Alzarri Joseph': 'PERSON',
#  'the Rajiv Gandhi International Cricket Stadium': 'ORG',
#  'K.V.S. Giri': 'PERSON',
#  'Sunrisers Hyderabad': 'PERSON',
#  'Ashwin': 'ORG',
#  'K.L. Rahul': 'PERSON',
#  'Sarfaraz Khan': 'PERSON',
#  'Murugan': 'PERSON',
#  'Sunrisers': 'GPE',
#  'the David Warner': 'ORG',
#  'Kane Williamson’s': 'PERSON',
#  'Bhuvneshwar': 'PERSON',
#  'Siddharth Kaul': 'PERSON',
#  'Rashid Khan': 'PERSON',
#  'VIVO': 'ORG',
#  'AP': 'ORG',
#  'Joseph': 'PERSON',
#  'Sohail Tanvir’s': 'PERSON',
#  'Andrew Tye’s': 'PERSON',
#  'Vijay Shankar': 'PERSON',
#  'Wankhede': 'PERSON',
#  'Kaul': 'PERSON',
#  'Royal': 'ORG',
#  'Delhi Capitals ( DC': 'ORG',
#  'M Chinnaswamy': 'ORG',
#  'K. Bhagya': 'PERSON',
#  'Kennedy': 'PERSON',
#  'Benevolence': 'PERSON',
#  'Fanfare': 'ORG',
#  'Sandesh 56.5': 'PERSON',
#  'Retained Asset': 'PERSON',
#  'Dashrath 49.5': 'PERSON',
#  'BENEVOLENCE': 'ORG',
#  'FANFARE': 'ORG',
#  'Galloping Goldmine': 'PERSON',
#  'Kanadario': 'PERSON',
#  'Va Danser': 'ORG',
#  'Dashrath 55': 'PERSON',
#  'B. Nikhil 53.5': 'PERSON',
#  'Caprisca': 'ORG',
#  'Fifty Two': 'PERSON',
#  'Turning Point': 'ORG',
#  'Dashrath 50.5': 'PERSON',
#  'Kilkarry Bridge': 'PERSON',
#  'Peter 62': 'PERSON',
#  'Pricelessgirl': 'ORG',
#  'Ayyar 59.5': 'PERSON',
#  'Impala': 'PERSON',
#  'Civilian': 'ORG',
#  'Harmony Of The Sea': 'PERSON',
#  'Bhawani 52.5': 'PERSON',
#  'Arabian Friend': 'ORG',
#  'KIKLKARRY BRIDGE': 'ORG',
#  'EL COMANDANTE': 'ORG',
#  'Peter 59': 'PERSON',
#  'Ustad Pedro': 'PERSON',
#  'Sensex': 'ORG',
#  'Ajinkya 55.5': 'PERSON',
#  'Nazil 54.5': 'PERSON',
#  'Rapid Girl': 'PERSON',
#  'Samurai': 'PERSON',
#  'Silver Cap': 'PERSON',
#  'USTAD PEDRO': 'ORG',
#  'Gandalf': 'PERSON',
#  'Ajinkya 58.5': 'PERSON',
#  'Godsword': 'PERSON',
#  'Hexahedron': 'ORG',
#  'Parmar 57.5': 'PERSON',
#  'Golden Horde': 'PERSON',
#  '8)': 'ORG',
#  'Cracklin': 'ORG',
#  'Highland Wind': 'PERSON',
#  'Dashrath 52': 'PERSON',
#  'Wizard': 'PERSON',
#  'GANDALF': 'ORG',
#  'CRACKLIN': 'ORG',
#  'KILKARRY BRIDGE': 'ORG',
#  'PowerPlay': 'ORG',
#  'Jonny Bairstow': 'PERSON',
#  'Rahul Chahar': 'PERSON',
#  'Manish Pandey': 'ORG',
#  'Yusuf Pathan': 'PERSON',
#  'Chahar': 'PERSON',
#  'Mohammad Nabi': 'PERSON',
#  'Siddarth Kaul': 'PERSON',
#  'Skipper Rohit Sharma': 'PERSON',
#  'Nabi': 'ORG',
#  'Sandeep Sharma': 'PERSON',
#  'Suryakumar Yadav': 'PERSON',
#  'Quinton de Kock': 'ORG',
#  'Pollard’s': 'ORG',
#  'Isaak Hayik': 'ORG',
#  'Hayik': 'PERSON',
#  'Israel': 'GPE',
#  'Yehuda': 'PERSON',
#  '’m': 'PERSON',
#  'Maccabi Ramat Gan': 'PERSON',
#  'Robert Carmona': 'PERSON',
#  'Uruguay': 'GPE',
#  'Uruguay’s': 'ORG',
#  'Guinness World Records': 'ORG',
#  'Jofra Archer': 'PERSON',
#  'ARCHER': 'PERSON',
#  'Chris Jordan': 'PERSON',
#  'Sussex': 'GPE',
#  'Barbados': 'PERSON',
#  'R. Ashwin Mankading Buttler': 'PERSON',
#  'Bumrah’s': 'ORG',
#  'Bumrah': 'PERSON',
#  'Ambrose': 'PERSON',
#  'Michael Holding': 'PERSON',
#  'Shreyas Iyer': 'PERSON',
#  'Kumar A.': 'PERSON',
#  'Ajinkya Rahane': 'PERSON',
#  'Hurricane Andre': 'PERSON',
#  'Russell’s': 'ORG',
#  'Karthik, Robin Uthappa': 'ORG',
#  'Ben Sokes': 'PERSON',
#  'K. Gowtham': 'PERSON',
#  'Gopal': 'PERSON',
#  'Shimron Hetmyer': 'PERSON',
#  'Sanju Samson': 'PERSON',
#  'Scott Kuggeleijn': 'GPE',
#  'Photo Credit': 'ORG',
#  'New Zealand': 'GPE',
#  'Lungi Ngidi': 'ORG',
#  'Ngidi': 'ORG',
#  'Kuggeleijn': 'GPE',
#  'Against Capitals': 'ORG',
#  'Rishabh Pant': 'PERSON',
#  'Kings XI': 'PERSON',
#  'Chris Gayle': 'PERSON',
#  'Dhoni': 'GPE',
#  'Rahul': 'PERSON',
#  'David Milller’s': 'PERSON',
#  'Sarfraz Khan': 'PERSON',
#  'Kings': 'PERSON',
#  'Harbhajan': 'PERSON',
#  'Man-of-': 'PERSON',
#  'Mayank Agarwal': 'PERSON',
#  'Sarfaraz': 'PERSON',
#  'Leg-spinner': 'PERSON',
#  'Chepauk': 'ORG',
#  'FIFA': 'ORG',
#  'Gianni Infantino': 'PERSON',
#  'AFC': 'ORG',
#  'Praful Patel': 'PERSON',
#  'the Asian Football Confederation Congress': 'ORG',
#  'Kuala Lumpur': 'GPE',
#  'Patel': 'ORG',
#  'the FIFA Council': 'ORG',
#  'All India Football Federation': 'ORG',
#  'AIFF': 'ORG',
#  'Memorandum': 'PERSON',
#  'Shaikh Salman bin': 'PERSON',
#  'Al Khalifa': 'PERSON',
#  'Shaikh Salman': 'PERSON',
#  '— FIFA Council': 'ORG',
#  'Female': 'ORG',
#  'AFC Executive Committee': 'ORG',
#  'Congress': 'ORG',
#  'Kushal Das': 'PERSON',
#  'Subrata Datta': 'PERSON',
#  'AFC (Asian Football Confederations)': 'ORG',
#  'LPGA': 'ORG',
#  'Pak Se Ri': 'PERSON',
#  'Lorena Ochoa': 'PERSON',
#  'Nancy Lopez': 'PERSON',
#  'Augusta National Women’s Amateur': 'ORG',
#  'American Anna Redding': 'ORG',
#  'University of Virginia': 'ORG',
#  'Augusta National’s': 'ORG',
#  'Darla Moore': 'PERSON',
#  'State': 'ORG',
#  'Condoleezza Rice': 'PERSON',
#  'Pak': 'ORG',
#  'Ochoa': 'PERSON',
#  'Lopez and Sorenstam': 'ORG',
#  'Rajasthan Royals’ Jos Buttler': 'ORG',
#  'Mankad': 'PERSON',
#  'Vinoo Mankad': 'PERSON',
#  'Bill Brown': 'PERSON',
#  'Don Bradman': 'PERSON',
#  'Laws': 'PERSON',
#  'Bowler': 'ORG',
#  'MCC': 'ORG',
#  'the International Cricket Council Match Officials’': 'ORG',
#  'Lahore': 'GPE',
#  'Courtney Walsh': 'PERSON',
#  'Saleem Jaffar': 'PERSON',
#  'West Indies': 'ORG',
#  'Batsmen': 'PERSON',
#  'Cricket': 'PERSON',
#  'Spirit': 'PERSON',
#  'Stephen Wagg': 'PERSON',
#  'Amateurs': 'GPE',
#  'Law': 'PERSON',
#  'Englishman': 'PERSON',
#  'The ICC Match Officials’ Almanac': 'ORG',
#  'Fraser Stewart': 'PERSON',
#  'Macau': 'GPE',
#  'Sedgefield': 'PERSON',
#  '600/41': 'ORG',
#  'Dance Emperor': 'PERSON',
#  'Flammeus': 'PERSON',
#  'Song': 'PERSON',
#  'Shubham': 'PERSON',
#  'Ben Stokes': 'PERSON',
#  'File\n\xa0 |': 'ORG',
#  'AP England’s': 'ORG',
#  'Bristol': 'ORG',
#  'Stokes': 'PERSON',
#  'Bristol Crown Court': 'ORG',
#  'Wales Cricket Board’s Discipline Commission': 'ORG',
#  'ECB': 'ORG',
#  'Hardus Viljoen': 'ORG',
#  'Mujeeb-ur-': 'ORG',
#  'Balwant Singh': 'PERSON',
#  'ATK': 'ORG',
#  'Manuel Lanzarote': 'PERSON',
#  'Mohammad Sajid': 'PERSON',
#  'Daniel Lalhlimpuia': 'PERSON',
#  'S. Nadhakumar': 'PERSON',
#  'Adria Carmona': 'GPE',
#  'Lanzarote': 'ORG',
#  'Albino Gomes': 'PERSON',
#  'Jayesh Rane': 'PERSON',
#  'Balwant': 'ORG',
#  'Rane': 'PERSON',
#  'John Johnson': 'PERSON',
#  'Lallianzuala Chhangte': 'PERSON',
#  'S. Nadhakumar’s': 'PERSON',
#  'Andre Bike': 'PERSON',
#  'S. Nadhakumar 72': 'PERSON',
#  'Premier League': 'ORG',
#  'Sydney': 'GPE',
#  'Warner': 'ORG',
#  'Rajathan Royals': 'ORG',
#  'Hardik Pandya': 'GPE',
#  'Karan Johar': 'PERSON',
#  'Hardik': 'ORG',
#  'Sujith Somasunder': 'PERSON',
#  'India Test': 'ORG',
#  'Sujith': 'PERSON',
#  'Gazino': 'PERSON',
#  'R R KOMANDUR PLATE': 'PERSON',
#  'Sandesh 54.5': 'PERSON',
#  'Sorrento': 'PERSON',
#  'Western Front': 'ORG',
#  'Lucky Luciano': 'PERSON',
#  'Dashrath 50': 'PERSON',
#  'AHMED': 'ORG',
#  'II': 'PERSON',
#  'Cellini': 'PERSON',
#  'J. Chinoy': 'PERSON',
#  'Storm Eagle': 'PERSON',
#  'Thea’s Fire': 'ORG',
#  'S. Amit 55': 'PERSON',
#  'Chephirah': 'PERSON',
#  'Zervan 53.5': 'PERSON',
#  'Flaming Passion': 'ORG',
#  'S. Kamble 53.5': 'PERSON',
#  'Judy Blue Eyes': 'PERSON',
#  'Periwinkle': 'ORG',
#  'Neeraj 53.5': 'PERSON',
#  'Turmeric Tower': 'PERSON',
#  'Dashrath 53.5': 'PERSON',
#  'Whydah': 'PERSON',
#  'Wonder Girl': 'PERSON',
#  'Divine Hunt': 'PERSON',
#  'A. Gaikwad': 'PERSON',
#  'Majestic Warrior': 'PERSON',
#  'Mzilkazi': 'PERSON',
#  'Saltbae': 'ORG',
#  'Valiant Star': 'ORG',
#  'Bunde': 'PERSON',
#  'Sandesh 53.5': 'PERSON',
#  'Dancing Jade': 'PERSON',
#  'God’s Decree': 'PERSON',
#  'T.S.': 'GPE',
#  'Principessa': 'PERSON',
#  'S. Chinoy 53.5': 'PERSON',
#  'BELENUS': 'ORG',
#  'Dashrath 59': 'PERSON',
#  'Holy Smoke': 'PERSON',
#  'Zervan 55.5': 'PERSON',
#  'Thomas Hardy': 'PERSON',
#  'Adonijah': 'PERSON',
#  'D.A. Naik 58': 'PERSON',
#  'Gentillesse': 'PERSON',
#  'Dragon': 'PERSON',
#  'Arizona Pie': 'ORG',
#  'Chezza': 'PERSON',
#  'THOMAS HARDY': 'PERSON',
#  'MONIFIETH PLATE': 'ORG',
#  'B. Nikhil 60.5': 'PERSON',
#  'Shivalik Queen': 'PERSON',
#  'S. Chinoy 54.5': 'PERSON',
#  'Sandalphon': 'PERSON',
#  'Peter 54': 'PERSON',
#  'Thea’s': 'ORG',
#  'Speedo': 'PERSON',
#  'SHIVALIK QUEEN': 'ORG',
#  'AB de Villiers': 'ORG',
#  'K. Murali Kumar': 'PERSON',
#  'RCB’s': 'ORG',
#  'Mohammed Siraj': 'PERSON',
#  'de Villiers': 'ORG',
#  'Parthiv': 'PERSON',
#  'Sachin Tendulkar': 'PERSON',
#  'Ferguson': 'PERSON',
#  'Kuldeep': 'ORG',
#  'Extras': 'PERSON',
#  'Prasidh 3-0-41-0,': 'PERSON',
#  'KOLKATA KNIGHT': 'PERSON',
#  'Negi': 'ORG',
#  'Chahal': 'ORG',
#  'Uthappa': 'ORG',
#  'Vivek Bendre Mumbai Indians’': 'ORG',
#  'Suryakumar': 'PERSON',
#  'Lasith': 'PERSON'}

# %% [markdown]
# ## Performing sentimental analysis for each entity detected in all the articles. The method also involves checking upto 3 sentences ahead if the entity is found in a sentence, to include the further sentences with pronouns for the same entity.

# %%
# loop through the sentences containing each NER can calculate the sentiment score and average it.
def getSentimentScore(term, corpus):
    sia = SentimentIntensityAnalyzer()
    scores = []
    sentences = sent_tokenize(corpus)
    weights = [1, 0.75, 0.5, 0.25]
    for i in range(len(sentences)):
        sentence = sentences[i]
        if term in sentence:
            scores.append(sia.polarity_scores(sentence)['compound'])
            x = i+1
            while(x < len(sentences) and x-i <= 3):
                if term in sentences[x]:
                    break
                for word, tag in pos_tag(word_tokenize(sentences[x])):
                    if tag in ['PRP', 'PRP$']:
                        scores.append(sia.polarity_scores(sentences[x])['compound'] * weights[x-i])
                        break
                x += 1

    avg_sent_score = round(sum(scores)/len(scores), 5) if len(scores)>0 else 0
    return avg_sent_score

# %%
# organising the enities and their scores in a dictionary on the base of entity types
nes = getNE(corpus)
sent_scores = {}
for ne in nes:
    ne_tag = nes[ne]
    if ne_tag not in sent_scores:
        sent_scores[ne_tag] = []
    sent_scores[ne_tag].append((ne, getSentimentScore(ne, corpus)))

# %%
# Sorting the entities in increasing order of sentiment score.
for ne_tag in sent_scores:
    sent_scores[ne_tag] = sorted(sent_scores[ne_tag], key=lambda x: x[1])

# %%
pprint(sent_scores)
# Out:
# {'GPE': [('Taipei', -0.3182),
#          ('Rabada', -0.14287),
#          ('New Zealand', -0.13207),
#          ('Dabang', -0.00513),
#          ('Dabang Delhi', -0.00513),
#          ('Makati', 0.0),
#          ('Tejal Hasabnis', 0.0),
#          ('Istanbul', 0.0),
#          ('₹16', 0.0),
#          ('Zervan', 0.0),
#          ('T.S.', 0.0),
#          ('Tanala', 0.00513),
#          ('Adria Carmona', 0.00967),
#          ('Stuart Binny', 0.01067),
#          ('Lahore', 0.03046),
#          ('Uppal', 0.03937),
#          ('Hainan', 0.04267),
#          ('Spain', 0.06813),
#          ('Santa Singh', 0.0683),
#          ('Dhoni', 0.06852),
#          ('Sussex', 0.06899),
#          ('Amateurs', 0.0734),
#          ('Paltan', 0.07616),
#          ('UAE', 0.08131),
#          ('Malaysia', 0.09001),
#          ('Punjab', 0.09233),
#          ('Ankit Rajpoot', 0.11333),
#          ('Sydney', 0.11702),
#          ('West Bengal', 0.1184),
#          ('Kolkata', 0.12691),
#          ('Philippines', 0.13639),
#          ('Patna Pirates', 0.13811),
#          ('Iran', 0.13963),
#          ('Naveen', 0.13986),
#          ('Pune', 0.14125),
#          ('Australia', 0.145),
#          ('US', 0.14525),
#          ('England', 0.15321),
#          ('Hockey India', 0.15326),
#          ('Simran', 0.15923),
#          ('Minnu Mani', 0.15923),
#          ('Sunrisers', 0.16236),
#          ('Scott Kuggeleijn', 0.16859),
#          ('Kuggeleijn', 0.17055),
#          ('Mexico', 0.17105),
#          ('UK', 0.1909),
#          ('India', 0.19314),
#          ('Mumbai', 0.19454),
#          ('Jaipur', 0.20242),
#          ('Amsterdam', 0.20883),
#          ('United Kingdom', 0.21075),
#          ('Lucknow', 0.2134),
#          ('Uruguay', 0.21714),
#          ('Bengaluru', 0.21901),
#          ('Hyderabad', 0.2197),
#          ('Macau', 0.2202),
#          ('Hardik Pandya', 0.2235),
#          ('Pakistan', 0.23929),
#          ('Israel', 0.24265),
#          ('Barcelona', 0.24407),
#          ('PayTm', 0.24597),
#          ('the Netherlands', 0.24754),
#          ('Netherlands', 0.24754),
#          ('Mohali', 0.24767),
#          ('Chennai', 0.2687),
#          ('Philadelphia', 0.2997),
#          ('Harendra', 0.30107),
#          ('Kuala Lumpur', 0.40404),
#          ('Visakhapatnam', 0.4187),
#          ('Golfer-of', 0.42156),
#          ('Jakarta', 0.5267),
#          ('Georgia', 0.54215),
#          ('Chaitanya', 0.5994),
#          ('Hong Kong', 0.6369),
#          ('Ranchi', 0.6486),
#          ('Bundesliga', 0.8555)],
#  'ORG': [('Rajathan Royals', -0.7717),
#          ('Golden Steal (Rupesh)', -0.4939),
#          ('Quinton de Kock', -0.3612),
#          ('Thea’s Fire', -0.34),
#          ('RCB’s', -0.31014),
#          ('Desai &', -0.296),
#          ('Zaveri Stud Farm Pvt Ltd.', -0.296),
#          ('The ICC Match Officials’ Almanac', -0.19317),
#          ('India Test', -0.1849),
#          ('Thea’s', -0.17),
#          ('Aussie', -0.16776),
#          ('Rio', -0.16776),
#          ('Manish Pandey', -0.1591),
#          ('ECB', -0.15731),
#          ('Ishant', -0.13121),
#          ('State', -0.128),
#          ('Lopez and Sorenstam', -0.125),
#          ('Air India', -0.10225),
#          ('Moeen', -0.07563),
#          ('Nabi', -0.04894),
#          ('American Anna Redding', -0.048),
#          ('University of Virginia', -0.048),
#          ('Hardus Viljoen', -0.048),
#          ('Mujeeb-ur-', -0.048),
#          ('Bumrah’s', -0.04795),
#          ('the BCCI Technical Committee', -0.04688),
#          ('the IPL Technical Committee', -0.04688),
#          ('the IPL Governing Council', -0.04688),
#          ('the China Golf Association', -0.02653),
#          ('PKL’s', -0.0258),
#          ('Gurney', -0.02093),
#          ('Royal Challengers Bangalore’s', -0.01571),
#          ('the Apex Council of the BCCI', -0.01562),
#          ('the Cricket Committees', -0.01562),
#          ('RCB de Villiers', -0.01449),
#          ('Ishant Sharma', -0.01449),
#          ('Ashwin', -0.01287),
#          ('Ravinder Pahal (Dabang Delhi', -0.01284),
#          ('Parvesh Bainswal (Gujarat Fortunegiants', -0.01284),
#          ('Rishank Devadiga', -0.01284),
#          ('UP Yodhas', -0.01284),
#          ('Yodhas', -0.01284),
#          ('Chawla', -0.0102),
#          ('Bowler', -0.00643),
#          ('Kolhapur', 0.0),
#          ('Master Of Studies (Rathod', 0.0),
#          ('Indian Premiere League', 0.0),
#          ('Kolkata Knight Riders and Delhi Capitals', 0.0),
#          ('The Committee of Administrators', 0.0),
#          ('Cricket Australia', 0.0),
#          ('Priya Punia', 0.0),
#          ('Yastika Bhatia', 0.0),
#          ('B.C. Ramesh (Bengal Warriors', 0),
#          ('Bhaskaraan (Tamil Thalaivas', 0.0),
#          ('A.B. de Villiers', 0),
#          ('M.D. PETIT PLATE', 0),
#          ('DIEGO RIVERA PLATE', 0.0),
#          ('DT Racing & Breeders LLP', 0.0),
#          ('M/s', 0.0),
#          ('Ajay K. Arora &', 0.0),
#          ('Turning Point (Dashrath', 0.0),
#          ('Five Stars Shipping', 0.0),
#          ('Pvt.', 0.0),
#          ('El Comandante', 0.0),
#          ('Poonawalla Racing &', 0.0),
#          ('Dinsha P. Shroff &', 0.0),
#          ('KAZAKH PLATE', 0.0),
#          ('Geoffrey B. Nagpal & Nishant G. Nagpal', 0.0),
#          ('BEJAN BHARUCHA PLATE', 0.0),
#          ('₹23', 0.0),
#          ('800/50', 0.0),
#          ('Fanfare', 0.0),
#          ('Va Danser', 0.0),
#          ('Caprisca', 0.0),
#          ('Turning Point', 0.0),
#          ('Pricelessgirl', 0.0),
#          ('Civilian', 0.0),
#          ('KIKLKARRY BRIDGE', 0.0),
#          ('EL COMANDANTE', 0.0),
#          ('Sensex', 0.0),
#          ('USTAD PEDRO', 0.0),
#          ('Hexahedron', 0.0),
#          ('Cracklin', 0.0),
#          ('GANDALF', 0.0),
#          ('CRACKLIN', 0.0),
#          ('KILKARRY BRIDGE', 0.0),
#          ('AFC (Asian Football Confederations)', 0.0),
#          ('Rajasthan Royals’ Jos Buttler', 0.0),
#          ('Western Front', 0.0),
#          ('AHMED', 0.0),
#          ('Periwinkle', 0.0),
#          ('Saltbae', 0.0),
#          ('Valiant Star', 0.0),
#          ('BELENUS', 0.0),
#          ('Arizona Pie', 0.0),
#          ('MONIFIETH PLATE', 0.0),
#          ('Negi', 0.0),
#          ('Chahal', 0.0),
#          ('Piyush Chawla', 0.00856),
#          ('Prashant Chopra', 0.01067),
#          ('Captain & WK', 0.01284),
#          ('K C Cariappa', 0.01284),
#          ('Retained Elite Players:', 0.0258),
#          ('Bengal Warriors:', 0.0258),
#          ('600/40', 0.02753),
#          ('Smith', 0.03171),
#          ('Gujarat Fortunegiants', 0.03541),
#          ('800/54', 0.0367),
#          ('TNCA', 0.03707),
#          ('SAI', 0.03847),
#          ('Final Bid Match', 0.04206),
#          ('MCC', 0.0423),
#          ('Armaan', 0.04553),
#          ('Shreyas', 0.04671),
#          ('the International Cricket Council Match Officials’', 0.04765),
#          ('Premier League’s', 0.04863),
#          ('Southee', 0.04899),
#          ('Kuldeep', 0.05016),
#          ('Red Chillies Entertainment Private Limited', 0.05077),
#          ('ODI', 0.05109),
#          ('Hardik', 0.05226),
#          ('Lungi Ngidi', 0.05237),
#          ('Golden Era (Baria', 0.05303),
#          ('the Rajiv Gandhi International Cricket Stadium', 0.05428),
#          ('Caesar (Chouhan', 0.05505),
#          ('Anirudh Chaudhry', 0.06197),
#          ('Players’ Association', 0.06588),
#          ('Lanzarote', 0.07362),
#          ('India Blue: Devika', 0.07961),
#          ('AP England’s', 0.0798),
#          ('PowerPlay', 0.08052),
#          ('The Tamil Nadu Cricket Association', 0.08685),
#          ('the David Warner', 0.08838),
#          ('BCCI', 0.08911),
#          ('the Delhi Capitals', 0.0903),
#          ('de Villiers', 0.09068),
#          ('Committee of Administrators', 0.09194),
#          ('Desai', 0.09411),
#          ('West Indies', 0.09825),
#          ('The Players’ Association', 0.09882),
#          ('U Mumba', 0.0999),
#          ('Bristol', 0.10257),
#          ('AB de Villiers', 0.1027),
#          ('Kiwi', 0.10378),
#          ('Nitish Rana', 0.10756),
#          ('ATK', 0.10822),
#          ('the Sports Ministry', 0.10881),
#          ('AP', 0.11028),
#          ('KXIP', 0.11333),
#          ('Chepauk', 0.1147),
#          ('Royals', 0.11527),
#          ('Reid’s', 0.1205),
#          ('Warner', 0.12077),
#          ('Kunal', 0.1208),
#          ('Balwant', 0.12187),
#          ('Knight Riders’', 0.123),
#          ('RCB', 0.12417),
#          ('File\n\xa0 | Photo Credit', 0.12567),
#          ('File\n\xa0 |', 0.12567),
#          ('600/41', 0.12573),
#          ('Delhi Capitals', 0.13536),
#          ('Chouhan', 0.14222),
#          ('Augusta National Golf Club', 0.14675),
#          ('Ngidi', 0.14776),
#          ('The Star', 0.14801),
#          ('Capitals', 0.15046),
#          ('’s IPL', 0.15163),
#          ('Uthappa', 0.15233),
#          ('Girish Ernak', 0.15512),
#          ('Parmar', 0.15635),
#          ('Royal', 0.15821),
#          ('Trevor', 0.1603),
#          ('Puneri Paltan', 0.16143),
#          ('Knight Riders', 0.16164),
#          ('Pranil', 0.16215),
#          ('Regal Shot (Bhawani', 0.16515),
#          ('IPL', 0.17967),
#          ('Kohli', 0.1826),
#          ('Rajasthan Royals', 0.18305),
#          ('8)', 0.18546),
#          ('AP India’s', 0.1909),
#          ('Pak', 0.19449),
#          ('Robin Uthappa', 0.19534),
#          ('CSK', 0.19683),
#          ('PKL', 0.20103),
#          ('PGA', 0.20209),
#          ('ProKabaddi League', 0.20413),
#          ('Justice', 0.20435),
#          ('— FIFA Council', 0.20563),
#          ('Female', 0.20563),
#          ('AFC Executive Committee', 0.20563),
#          ('KKR', 0.20566),
#          ('the Sports Authority of India', 0.20573),
#          ('the FIFA Council', 0.20589),
#          ('HI', 0.20763),
#          ('& WK', 0.20836),
#          ('Pair', 0.21259),
#          ('CAB', 0.21364),
#          ('Faf du Plessis', 0.2152),
#          ('RR', 0.21576),
#          ('Uruguay’s', 0.21714),
#          ('Guinness World Records', 0.21714),
#          ('Photo Credit', 0.22123),
#          ('PTI', 0.22617),
#          ('Young Players', 0.2263),
#          ('Retained Young Players', 0.2263),
#          ('Premier League', 0.2275),
#          ('the Committee of Administrators', 0.22985),
#          ('Augusta National’s', 0.22987),
#          ('FIFA', 0.23634),
#          ('Olympic', 0.23715),
#          ('Azhar Mahmood', 0.23734),
#          ('FBM', 0.23878),
#          ('U Mumba and Tamil Thalaivas', 0.23892),
#          ('AFC', 0.24021),
#          ('Isaak Hayik', 0.24214),
#          ('Kabaddi League', 0.24746),
#          ('Nazil', 0.25296),
#          ('Patel', 0.257),
#          ('Congress', 0.26315),
#          ('Gholamreza', 0.26472),
#          ('Royal Challengers Bangalore', 0.26481),
#          ('Fleming', 0.26746),
#          ('India Blue', 0.26927),
#          ('AIFF', 0.27918),
#          ('the Indian Premier League', 0.28095),
#          ('Pollard’s', 0.28546),
#          ('LPGA', 0.28704),
#          ('Augusta National Women’s Amateur', 0.28704),
#          ('Russell’s', 0.29105),
#          ('Ustad Pedro (', 0.2997),
#          ('Against Capitals', 0.3034),
#          ('Ombudsman', 0.3075),
#          ('National', 0.30791),
#          ('Augusta National', 0.31162),
#          ('Bristol Crown Court', 0.31381),
#          ('Wales Cricket Board’s Discipline Commission', 0.31381),
#          ('FANFARE', 0.3243),
#          ('Arthur', 0.33553),
#          ('Vivek Bendre Mumbai Indians’', 0.33788),
#          ('Sawai Man Singh', 0.35961),
#          ('Masters', 0.36746),
#          ('Chennai Super Kings', 0.37115),
#          ('the Sports Authority of India Centre', 0.373),
#          ('Women’s IPL', 0.4187),
#          ('All India Football Federation', 0.41877),
#          ('Delhi Capitals ( DC', 0.41941),
#          ('M Chinnaswamy', 0.41941),
#          ('Trio', 0.4404),
#          ('Divine Power (S.J.Sunil', 0.44385),
#          ('Silver Flames (Sandesh', 0.44385),
#          ('SHIVALIK QUEEN', 0.45275),
#          ('Steppenwolf', 0.4588),
#          ('Flaming Passion', 0.4588),
#          ('Charlesworth’s', 0.47052),
#          ('Arabian Friend', 0.4939),
#          ('Karthik, Robin Uthappa', 0.5106),
#          ('Butler Cabin', 0.54215),
#          ('VIVO', 0.57132),
#          ('P. Trevor', 0.5719),
#          ('Career', 0.58203),
#          ('the Asian Football Confederation Congress', 0.58381),
#          ('K M Asif', 0.5994),
#          ('N Jagadeesan', 0.5994),
#          ('Vivek Bendre Retained', 0.6124),
#          ('the ProKabaddi League', 0.6124),
#          ('Augusta National GC & @TheMasters', 0.6211),
#          ('the India Red', 0.6486),
#          ('the U-23 Women’s One-', 0.6486),
#          ('Brazos (Pranil', 0.6486),
#          ('BENEVOLENCE', 0.67795),
#          ('Grey Falcon (Kaviraj', 0.7351),
#          ('Bayern Munich', 0.8555),
#          ('Gallantry (Kamble', 0.8934)],
#  'PERSON': [('Mayank Agarwal', -0.4404),
#             ('John Johnson', -0.4019),
#             ('Lallianzuala Chhangte', -0.4019),
#             ('Sandeep Sharma', -0.3612),
#             ('Sedgefield', -0.3612),
#             ('Suni Narine', -0.32985),
#             ('Sarfaraz Khan', -0.31861),
#             ('Lin Yun-Ju', -0.3182),
#             ('Kagiso Rabada', -0.31026),
#             ('Champaklal Zaveri', -0.296),
#             ('Bindu C. Zaveri', -0.296),
#             ('Harsha N Desai', -0.296),
#             ('S.S. Shah', -0.296),
#             ('Karnataka', -0.2294),
#             ('Lin', -0.18787),
#             ('Spirit', -0.1849),
#             ('Sujith Somasunder', -0.1849),
#             ('S. Amit 55', -0.17),
#             ('Jamie Dwyer', -0.16776),
#             ('David Milller’s', -0.1591),
#             ('Skipper Rohit Sharma', -0.1531),
#             ('Marcus Stoinis', -0.1528),
#             ('Mohammad Amir’s', -0.15252),
#             ('Sarfaraz Ahmed', -0.15252),
#             ('Lasith', -0.148),
#             ('Man-of-', -0.13712),
#             ('Darla Moore', -0.128),
#             ('Condoleezza Rice', -0.128),
#             ('Englishman', -0.12702),
#             ('Rahul Chahar', -0.10607),
#             ('Ashok Shinde', -0.10225),
#             ('Prasidh Krishna', -0.09799),
#             ('Fraser Stewart', -0.09698),
#             ('Daniel Lalhlimpuia', -0.08562),
#             ('S. Nadhakumar 72', -0.05816),
#             ('Fazel Atrachali', -0.0569),
#             ('Mankad', -0.05237),
#             ('Lionel Messi', -0.05135),
#             ('Law', -0.05056),
#             ('R. Ashwin Mankading Buttler', -0.05024),
#             ('Laws', -0.04298),
#             ('Sarfaraz', -0.02668),
#             ('Jeny', -0.02653),
#             ('Buttler', -0.01846),
#             ('Ben Sokes', -0.01804),
#             ('K. Gowtham', -0.01804),
#             ('Chahar', -0.01766),
#             ('Shreyas Iyer', -0.01564),
#             ('Harry Gurney', -0.0153),
#             ('Shreyas Gopal', -0.01353),
#             ('Jaideep', -0.01284),
#             ('Mahender Singh', -0.01284),
#             ('Chandran Ranjith', -0.01284),
#             ('Shrikant Jadhav', -0.01284),
#             ('Mohammad Nabi', -0.0091),
#             ('Manuel Lanzarote', -0.00656),
#             ('Mohammad Sajid', -0.00395),
#             ('Esmaeil Nabibaksh', 0.0),
#             ('Ayyar', 0.0),
#             ('Tasman', 0.0),
#             ('S.J. Sunil', 0),
#             ('Jack Flash', 0.0),
#             ('Gold Eclipse', 0.0),
#             ('M.S. Dhoni', 0),
#             ('Dhawal Kulkarni', 0.0),
#             ('R. Kalpana', 0.0),
#             ('S. Meghana', 0.0),
#             ('Ridhima Aggarwal', 0.0),
#             ('Ruzu Saha', 0.0),
#             ('C.H. Jhansilakshmi', 0),
#             ('Renuka Chaudhary,', 0.0),
#             ('Arundhati Reddy', 0.0),
#             ('Shanti Kumari', 0.0),
#             ('Devyani Prasad', 0.0),
#             ('Suman Meena', 0.0),
#             ('Shivali Shinde', 0.0),
#             ('Ayushi Garg', 0.0),
#             ('I.V. Drishya', 0),
#             ('Ekta Singh', 0.0),
#             ('Radha Yadav', 0.0),
#             ('Rashi Kanojia', 0.0),
#             ('Manali Dakshini', 0.0),
#             ('Renuka Singh', 0.0),
#             ('A. Akshaya', 0.0),
#             ('S. Anusha', 0.0),
#             ('Sanjeev Kumar Baliyan', 0.0),
#             ('Randhir Singh', 0.0),
#             ('Krishan Kumar Hooda', 0.0),
#             ('Manpreet Singh', 0.0),
#             ('Srinivas Reddy', 0.0),
#             ('Jaipur Pink Panthers', 0.0),
#             ('Ram Meher Singh', 0.0),
#             ('Sanjeev Kumar', 0.0),
#             ('Jasveer Singh', 0.0),
#             ('Rakesh Kumar', 0.0),
#             ('Pawan Kumar', 0.0),
#             ('Sandeep Kumar Dhoull', 0.0),
#             ('Pardeep Narwal', 0.0),
#             ('Vikas Jaglan', 0.0),
#             ('Tushar Patil', 0.0),
#             ('Jawahar', 0.0),
#             ('Ajay Thakur', 0.0),
#             ('Manjeet Chillar', 0.0),
#             ('Victor Onyango', 0.0),
#             ('Mohsen', 0.0),
#             ('Farhad Milaghardan', 0.0),
#             ('Nitin Madane', 0.0),
#             ('Rajguru Subramaniam', 0.0),
#             ('Arjun Deshwal', 0.0),
#             ('Sachin Kumar', 0.0),
#             ('C.K. Khanna', 0),
#             ('Sandeep Lamichhane', 0.0),
#             ('K.N. Dhunjibhoy', 0),
#             ('Z.K. Dhunjibhoy', 0),
#             ('Vispi R. Patel', 0.0),
#             ('S.K. Sunderji', 0),
#             ('K.H. Vaccha', 0),
#             ('Maiden', 0.0),
#             ('GOLDMINE', 0.0),
#             ('Wizard Of Stocks', 0.0),
#             ('Ramon', 0.0),
#             ('Goldmine', 0.0),
#             ('Mukul Sonawala', 0.0),
#             ('D.R. Thacker', 0),
#             ('₹10', 0.0),
#             ('Epiphany', 0.0),
#             ('Cyrus S. Poonawalla', 0.0),
#             ('Adar C. Poonawalla &', 0.0),
#             ('Natasha A. Poonawalla', 0.0),
#             ('Saleem Fazelbhoy', 0.0),
#             ('Munchi P. Shroff', 0.0),
#             ('Altaf Hussain', 0.0),
#             ('Cracklin Rosie', 0.0),
#             ('Nose', 0.0),
#             ('Agrami', 0.0),
#             ('Joplin', 0.0),
#             ('Furiosa', 0.0),
#             ('Nilesh', 0.0),
#             ('Dumas', 0.0),
#             ('Conscience', 0.0),
#             ('Niccolini', 0.0),
#             ('Akina Speed Star', 0.0),
#             ('K.V.S. Giri', 0),
#             ('K.L. Rahul', 0),
#             ('Kennedy', 0.0),
#             ('Sandesh 56.5', 0.0),
#             ('Galloping Goldmine', 0.0),
#             ('Kanadario', 0.0),
#             ('Dashrath 55', 0.0),
#             ('B. Nikhil 53.5', 0.0),
#             ('Fifty Two', 0.0),
#             ('Dashrath 50.5', 0.0),
#             ('Kilkarry Bridge', 0.0),
#             ('Peter 62', 0.0),
#             ('Ayyar 59.5', 0.0),
#             ('Impala', 0.0),
#             ('Bhawani 52.5', 0.0),
#             ('Peter 59', 0.0),
#             ('Ajinkya 55.5', 0.0),
#             ('Rapid Girl', 0.0),
#             ('Samurai', 0.0),
#             ('Silver Cap', 0.0),
#             ('Gandalf', 0.0),
#             ('Ajinkya 58.5', 0.0),
#             ('Godsword', 0.0),
#             ('Parmar 57.5', 0.0),
#             ('Golden Horde', 0.0),
#             ('Highland Wind', 0.0),
#             ('Dashrath 52', 0.0),
#             ('Yusuf Pathan', 0.0),
#             ('Siddarth Kaul', 0.0),
#             ('Ambrose', 0.0),
#             ('Michael Holding', 0.0),
#             ('Sarfraz Khan', 0.0),
#             ('Kushal Das', 0.0),
#             ('Subrata Datta', 0.0),
#             ('Dance Emperor', 0.0),
#             ('Flammeus', 0.0),
#             ('Karan Johar', 0.0),
#             ('R R KOMANDUR PLATE', 0.0),
#             ('Sandesh 54.5', 0.0),
#             ('II', 0.0),
#             ('Cellini', 0.0),
#             ('J. Chinoy', 0.0),
#             ('Storm Eagle', 0.0),
#             ('Chephirah', 0.0),
#             ('Zervan 53.5', 0.0),
#             ('Judy Blue Eyes', 0.0),
#             ('Neeraj 53.5', 0.0),
#             ('Turmeric Tower', 0.0),
#             ('Dashrath 53.5', 0.0),
#             ('Whydah', 0.0),
#             ('Wonder Girl', 0.0),
#             ('Majestic Warrior', 0.0),
#             ('Mzilkazi', 0.0),
#             ('Sandesh 53.5', 0.0),
#             ('Dancing Jade', 0.0),
#             ('God’s Decree', 0.0),
#             ('Principessa', 0.0),
#             ('S. Chinoy 53.5', 0.0),
#             ('Dashrath 59', 0.0),
#             ('Holy Smoke', 0.0),
#             ('Zervan 55.5', 0.0),
#             ('Adonijah', 0.0),
#             ('D.A. Naik 58', 0),
#             ('Chezza', 0.0),
#             ('B. Nikhil 60.5', 0.0),
#             ('Shivalik Queen', 0.0),
#             ('S. Chinoy 54.5', 0.0),
#             ('Sandalphon', 0.0),
#             ('Peter 54', 0.0),
#             ('Speedo', 0.0),
#             ('Extras', 0.0),
#             ('Prasidh 3-0-41-0,', 0.0),
#             ('KOLKATA KNIGHT', 0.0),
#             ('Rahane', 0.0015),
#             ('Chris Gayle', 0.00167),
#             ('Kuldeep Yadav', 0.00642),
#             ('Bengal Warriors', 0.0086),
#             ('Ahmad', 0.01057),
#             ('S. Midhun', 0.01067),
#             ('Varun Aaron', 0.01067),
#             ('Carlos Brathwaite', 0.01284),
#             ('Nikhil Naik', 0.01284),
#             ('Joe Denly', 0.01284),
#             ('Mundhe', 0.01284),
#             ('Sandeep Warrier', 0.01284),
#             ('Yarra Prithviraj', 0.01284),
#             ('Rishabh Pant', 0.01344),
#             ('Moeen Ali', 0.01375),
#             ('Ali', 0.01375),
#             ('John Reid', 0.01443),
#             ('Tour', 0.01828),
#             ('Rohit Kumar', 0.0258),
#             ('Pawan Kumar Sehrawat', 0.0258),
#             ('Sunil Kumar', 0.0258),
#             ('Baldev Singh', 0.0258),
#             ('Maninder Singh', 0.0258),
#             ('Joginder Narwal', 0.0258),
#             ('Kuldeep Singh', 0.0258),
#             ('Vikash Chandola', 0.0258),
#             ('Sujith', 0.02649),
#             ('S. Nadhakumar', 0.03034),
#             ('Courtney Walsh', 0.03046),
#             ('Saleem Jaffar', 0.03046),
#             ('Arie Irawan', 0.032),
#             ('Tim Southee', 0.03266),
#             ('Shikhar Dhawan', 0.03266),
#             ('Anup', 0.03368),
#             ('B.Nikhil', 0.0367),
#             ('Steve Smith', 0.03843),
#             ('Anup Kumar', 0.03929),
#             ('N. Rawal', 0.03977),
#             ('S. Amit', 0.04265),
#             ('Getty Images', 0.04267),
#             ('Bhuvneshwar Kumar', 0.04377),
#             ('Ferguson', 0.04512),
#             ('Chris Lynn', 0.04528),
#             ('Manpreet', 0.04553),
#             ('Mushtaque Ahmad', 0.04766),
#             ('Song', 0.04772),
#             ('R. Ashwin', 0.04886),
#             ('Prithvi Shaw', 0.04967),
#             ('Cricket', 0.04968),
#             ('Shinde', 0.05162),
#             ('Sachertorte', 0.05505),
#             ('Auspicious', 0.05505),
#             ('ARCHER', 0.05953),
#             ('Chris Jordan', 0.05953),
#             ('Sachin Talwar', 0.06179),
#             ('Amitabh Choudhary', 0.06197),
#             ('Navdeep Saini', 0.06277),
#             ('Ben Stokes', 0.06384),
#             ('Rahul', 0.06527),
#             ('Wizard', 0.06743),
#             ('Dipsan Tirkey', 0.0683),
#             ('Armaan Qureshi', 0.0683),
#             ('Vishal Bharadwaj', 0.0685),
#             ('Leg-spinner', 0.06972),
#             ('Arie', 0.07178),
#             ('Lynn', 0.07196),
#             ('Stephen Wagg', 0.0734),
#             ('Yoddha', 0.07462),
#             ('Albino Gomes', 0.0772),
#             ('Jos Buttler', 0.0776),
#             ('Kings XI Punjab', 0.07882),
#             ('Shaw', 0.0793),
#             ('Kings XI', 0.07977),
#             ('Lockie Ferguson', 0.08149),
#             ('Wankhede', 0.08296),
#             ('Bhuvneshwar', 0.08393),
#             ('Haryana Steelers', 0.08403),
#             ('Colin Ingram', 0.08481),
#             ('Marina Malek', 0.08933),
#             ('Narine', 0.08947),
#             ('Jofra Archer', 0.09066),
#             ('M. Ashwin', 0.09153),
#             ('Chris', 0.09293),
#             ('Bumrah', 0.0932),
#             ('Ganguly', 0.09358),
#             ('Kumar', 0.09918),
#             ('Yoddhas', 0.0995),
#             ('Monu Goyat', 0.10093),
#             ('Rashid Khan', 0.10128),
#             ('Tomar', 0.10341),
#             ('Deepak Hooda', 0.10812),
#             ('Mohd', 0.11065),
#             ('Sandeep', 0.11092),
#             ('Amit', 0.11388),
#             ('Abhijeet Mukherjee', 0.1184),
#             ('Bhaswati Shantua', 0.1184),
#             ('D K Jain', 0.1184),
#             ('Balwant Singh', 0.11963),
#             ('Delhi', 0.12206),
#             ('Nitin Tomar', 0.12409),
#             ('Rahul Dravid', 0.12467),
#             ('Ricky Ponting', 0.12798),
#             ('Mohammad Kaif', 0.12798),
#             ('Jonny Bairstow', 0.12841),
#             ('Josep Maria Bartomeu', 0.13323),
#             ('Jordi Mestre', 0.13323),
#             ('David Warner', 0.13326),
#             ('Tamil Thalaivas', 0.13394),
#             ('Kane Williamson’s', 0.1352),
#             ('Yuka Yasuda', 0.13639),
#             ('Yuka Saso', 0.13639),
#             ('Naveen Kumar', 0.13986),
#             ('Nitesh Kumar', 0.13986),
#             ('Siddharth Desai', 0.14087),
#             ('Batsmen', 0.14116),
#             ('Harbhajan', 0.14155),
#             ('Gentillesse', 0.14297),
#             ('Murugan', 0.14475),
#             ('Ajinkya Rahane', 0.14714),
#             ('Graham Reid’s', 0.14732),
#             ('Shubham', 0.14832),
#             ('Andre Russell', 0.14848),
#             ('Ochoa', 0.14969),
#             ('Sunil Narine', 0.14987),
#             ('Camp Nou', 0.15137),
#             ('Mohammed Siraj', 0.1531),
#             ('K. Murali Kumar', 0.15522),
#             ('Rahul Tripathi', 0.15593),
#             ('Nuzhat Parween', 0.15923),
#             ('Shefali Verma', 0.15923),
#             ('Tanushre Sarkar', 0.15923),
#             ('Prativa Rana', 0.15923),
#             ('Tanuja Kanwar', 0.15923),
#             ('C. Pratyusha', 0.15923),
#             ('Simran Dil Bahadur', 0.15923),
#             ('Kshama Singh', 0.15923),
#             ('Vrushali Bhagat', 0.15923),
#             ('Indrani Roy', 0.15923),
#             ('Shubman Gill', 0.1608),
#             ('Andrew Tye', 0.16293),
#             ('Gopal', 0.16453),
#             ('Minstrel Heights', 0.16515),
#             ('Jaykumar', 0.16515),
#             ('Amir', 0.16609),
#             ('Parthiv Patel', 0.16743),
#             ('Suryakumar', 0.16751),
#             ('Parthiv', 0.16787),
#             ('Robin', 0.16925),
#             ('’s', 0.1699),
#             ('Skipper Shreyas Iyer', 0.17006),
#             ('Stokes', 0.17087),
#             ('Kevin C. Cox', 0.17105),
#             ('Maria Fassi', 0.17105),
#             ('Virat Kohli', 0.17159),
#             ('CoA', 0.17343),
#             ('Russell', 0.17537),
#             ('Lamichhane', 0.17557),
#             ('Dravid', 0.17622),
#             ('Kolkata Knight Riders', 0.17669),
#             ('Memorandum', 0.17694),
#             ('Gholamreza Mazandarani', 0.1774),
#             ('Jayesh Rane', 0.17769),
#             ('S. Nadhakumar’s', 0.1779),
#             ('Andre Bike', 0.1779),
#             ('Peter', 0.1781),
#             ('Ric Charlesworth', 0.18113),
#             ('Reid', 0.18355),
#             ('Rishab Pant', 0.18522),
#             ('Sourav Ganguly', 0.18703),
#             ('Siddharth Kaul', 0.18979),
#             ('R. Ragu', 0.1909),
#             ('Sanju Samson', 0.19182),
#             ('Kaul', 0.19221),
#             ('Shane Watson', 0.19363),
#             ('Dinesh Karthik’s', 0.19522),
#             ('Kings', 0.19868),
#             ('Dinesh', 0.19874),
#             ('Sluman', 0.20116),
#             ('Chris Morris', 0.20246),
#             ('’m', 0.20292),
#             ('Maccabi Ramat Gan', 0.20292),
#             ('Joseph', 0.20332),
#             ('Charlesworth', 0.20392),
#             ('Karthik', 0.2044),
#             ('Bengaluru Bulls', 0.20466),
#             ('Yehuda', 0.20546),
#             ('Shaikh Salman bin', 0.20575),
#             ('Al Khalifa', 0.20575),
#             ('Max Caldas', 0.20883),
#             ('Dashrath 50', 0.21075),
#             ('Jain', 0.21397),
#             ('Dragon', 0.21446),
#             ('Dinesh Karthik', 0.21648),
#             ('Robert Carmona', 0.21714),
#             ('Don Bradman', 0.2212),
#             ('Imran Tahir', 0.22144),
#             ('Rane', 0.22383),
#             ('Rahul Chaudhari', 0.2263),
#             ('S. Kamble 53.5', 0.2294),
#             ('Graham Reid', 0.23101),
#             ('Golf', 0.23165),
#             ('DK Jain', 0.23379),
#             ('Mickey Arthur', 0.23734),
#             ('Bangalore', 0.23833),
#             ('Sachin Tendulkar', 0.23884),
#             ('Alzarri Joseph', 0.24471),
#             ('Harbhajan Singh', 0.24491),
#             ('Arrowhead', 0.25),
#             ('Stephen Fleming', 0.25334),
#             ('Jennifer Kupcho', 0.25672),
#             ('Vijay Shankar', 0.26353),
#             ('Deepak Chahar', 0.26435),
#             ('Hayik', 0.27098),
#             ('Lionel', 0.27111),
#             ('Messi', 0.27111),
#             ('David John', 0.2732),
#             ('Hurricane Andre', 0.27322),
#             ('Suryakumar Yadav', 0.28332),
#             ('Pak Se Ri', 0.28704),
#             ('Lorena Ochoa', 0.28704),
#             ('Nancy Lopez', 0.28704),
#             ('Sunrisers Hyderabad', 0.28926),
#             ('Harendra Singh', 0.29533),
#             ('Arms', 0.2992),
#             ('Ustad Pedro', 0.2997),
#             ('Fred Ridley', 0.31632),
#             ('Shubham Shinde', 0.32308),
#             ('Amit Singh', 0.32308),
#             ('Rajesh Mondal', 0.32308),
#             ('Sandeep Narwal', 0.32308),
#             ('Dwayne Bravo', 0.32332),
#             ('Sushree Dibyadarshini', 0.3243),
#             ('India Green', 0.3243),
#             ('Bunde', 0.33735),
#             ('Augusta', 0.34152),
#             ('Andrew Tye’s', 0.35315),
#             ('Vinoo Mankad', 0.35495),
#             ('Bill Brown', 0.35495),
#             ('Jetfire', 0.3592),
#             ('Gazino', 0.3592),
#             ('Shaikh Salman', 0.37224),
#             ('Inaugural @anwagolf', 0.373),
#             ('Harjeet Singh', 0.373),
#             ('Kupcho', 0.37317),
#             ('Dashrath 49.5', 0.3818),
#             ('Kumar A.', 0.3818),
#             ('Fassi', 0.39498),
#             ('Harmony Of The Sea', 0.4019),
#             ('Thomas Hardy', 0.4019),
#             ('S.S. Attaollahi', 0.4036),
#             ('K. Bhagya', 0.41941),
#             ('Lucky Luciano', 0.4215),
#             ('Shimron Hetmyer', 0.43516),
#             ('Shardul Thakur', 0.44177),
#             ('Mohit Sharma', 0.44177),
#             ('Praful Patel', 0.4554),
#             ('Benevolence', 0.48413),
#             ('Barbados', 0.50092),
#             ('Retained Asset', 0.5152),
#             ('Allauddin Khilji', 0.5267),
#             ('Rising Brave', 0.5267),
#             ('Andre Russell’s', 0.5375),
#             ('G. Sathiyan', 0.55729),
#             ('Divine Hunt', 0.5574),
#             ('A. Gaikwad', 0.5574),
#             ('Sohail Tanvir’s', 0.56217),
#             ('Jockey A. Sandesh', 0.5719),
#             ('Sorrento', 0.5719),
#             ('Rory McIlroy', 0.58203),
#             ('Gianni Infantino', 0.58381),
#             ('Luis', 0.59356),
#             ('Suarez', 0.59356),
#             ('Harisinghji Trophy', 0.5984),
#             ('MS Dhoni', 0.5994),
#             ('Murali Vijay', 0.5994),
#             ('Kedar Jadhav', 0.5994),
#             ('Sam Billings', 0.5994),
#             ('Ravindra Jadeja', 0.5994),
#             ('Dhruv Shorey', 0.5994),
#             ('Rituraj Gaikwad', 0.5994),
#             ('Karn Sharma', 0.5994),
#             ('Mitchell Santner', 0.5994),
#             ('Scott Kuggeleign', 0.5994),
#             ('Mario', 0.5994),
#             ('Nazil 54.5', 0.5994),
#             ('Jack Nicklaus', 0.6211),
#             ('Chun Ting Wong', 0.6369),
#             ('Day Challenger', 0.6486),
#             ('Suresh Raina', 0.66243),
#             ('Ambati Rayudu', 0.66243),
#             ('THOMAS HARDY', 0.7187),
#             ('Strong Values', 0.72675),
#             ('Super Sunshine', 0.8934)]}

# %%
print('Total NE detected:')
for ne_tag in sent_scores:
    print('{}: {}'.format(ne_tag, len(sent_scores[ne_tag])))
# Out:
# Total NE detected:
# PERSON: 508
# ORG: 274
# GPE: 76

# %% [markdown]
# ## Plotting the top and bottom N entities on the basis of sentiment score rankings.

# %%
def plotSentScores(data, n, features):
    if n>0:
        df = pd.DataFrame(data[-n:], columns=features)
        sb.barplot(data=df, y=features[0], x=features[1], orient='h', color='green')
    elif(n<0):
        df = pd.DataFrame(data[:abs(n)], columns=features)
        sb.barplot(data=df, y=features[0], x=features[1], orient='h', color='red')

# %%
plotSentScores(sent_scores['PERSON'], -30, ['Entity (Person)', 'Average Sentiment Score'])

# %%
plotSentScores(sent_scores['PERSON'], 30, ['Entity (Person)', 'Average Sentiment Score'])

# %%
plotSentScores(sent_scores['GPE'], -30, ['Entity (Geo-Political)', 'Average Sentiment Score'])

# %%
plotSentScores(sent_scores['GPE'], 30, ['Entity (Geo-Political)', 'Average Sentiment Score'])

# %%
plotSentScores(sent_scores['ORG'], -30, ['Entity (Organisation)', 'Average Sentiment Score'])

# %%
plotSentScores(sent_scores['ORG'], 30, ['Entity (Organisation)', 'Average Sentiment Score'])
