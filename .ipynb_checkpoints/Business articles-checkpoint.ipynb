# %% [markdown]
# # Performing NER and Sentimental Analysis on Business articles of The Hindu

# %%
# Import necessary packages
import nltk
from nltk.tokenize import word_tokenize, regexp_tokenize, sent_tokenize
from nltk.tag import pos_tag
from nltk.chunk import conlltags2tree, tree2conlltags
from nltk.text import TextCollection
from nltk.sentiment.vader import SentimentIntensityAnalyzer
from nltk.corpus import stopwords

import spacy
from spacy import displacy
from collections import Counter
nlp = spacy.load("en_core_web_sm")

from matplotlib import pyplot as plt
import seaborn as sb
# %matplotlib inline
import pandas as pd
import numpy as np

from pprint import pprint
from pymongo import MongoClient

# %% [markdown]
# ## Fetching the articles belonging to relevant collection

# %%
# fetch the article collection
client = MongoClient()
db = client["TheHindu"]
col = db['business']
article = []
for item in col.find():
    article.append(item['content'])
print('Number of articles found:', len(article))
# Out:
# Number of articles found: 51

# %%
# Basic exploration
corpus = ' '.join(article)
stoplist = stopwords.words('english')
tokens = [token for token in regexp_tokenize(corpus, '\w+') if len(token) > 1 and not token.isdigit() and token.lower() not in stoplist]
freqdist = nltk.FreqDist(tokens)
print('Total number of tokens found:', len(freqdist))
# Out:
# Total number of tokens found: 3487

# %%
sb.set(rc={'figure.figsize':(11.7,8.27)})
freqdist.plot(30)

# %% [markdown]
# ## Demonstrating NER on a single article using Spacy

# %%
# perform ner on each article
print(article[0])
# Out:
# With new model launches and aggressive sales promotion by carmakers failing to lift consumer sentiment, the passenger vehicle (PV) segment grew 2.7% in 2018-19, the slowest pace in the last five years, according to Society of Indian Automobile Manufacturers (SIAM). The current year is also expected to be a challenging one for the industry with the general elections in the first quarter, along with transition to BS VI technology later in the year, prompting the industry body to forecast a modest growth of 3-5% in sales of passenger vehicles for 2019-20. According to SIAM data, passenger vehicle sales in the last fiscal stood at 33,77,436 units, compared to 32,88,581 units in 2017-18. The 2.7% growth follows the original forecast of 8-10%, which was later revised to 6%. This is the slowest pace of growth for the industry since 2013-14, when sales declined 6.7%. SIAM president Rajan Wadhera called for a reduction in GST to offset the increase of 10-15% across vehicle categories prices due to BS VI implementation. “It is important to note that we are in election year. Historical data shows that the growth before the elections remains subdued,” he said. Other factors that affected demand included increase in insurance costs, a liquidity crunch and the highest-ever commodity prices that forced carmakers to raise vehicle prices, he added. “However, if we look at the positive side, we have continued to grow. Also, it is the highest-ever sales and production [achieved] in a financial year,” he added. Two-wheelers, the data showed, grew 4.85% in FY19, with the industry body forecasting growth of 5-7% for this fiscal. Likewise, commercial vehicles grew 17.55% in 2018-19 and are expected to see lower growth of 10-12% this year. Seeking lower taxes for the sector, Mr. Wadhera noted that the change in insurance policy has resulted in prices of two-wheelers rising by about 10%. This will go up further with introduction of BS VI. “The [Centre] should look at lowering GST for two-wheelers to 18% from 28%. The impact for cars will be higher with BS VI and other safety norms We need serious consideration from the government,” he said.

# %%
displacy.render(nlp(article[0]), jupyter=True, style='ent')
# Out:
# <div class="entities" style="line-height: 2.5; direction: ltr">With new model launches and aggressive sales promotion by carmakers failing to lift consumer sentiment, the passenger vehicle (
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     PV
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# ) segment grew
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     2.7%
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERCENT</span>
# </mark>
#  in
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     2018-19
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# , the slowest pace in
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     the last five years
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# , according to
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Society of Indian Automobile Manufacturers
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  (SIAM).
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     The current year
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  is also expected to be a challenging one for the industry with the general elections in
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     the first quarter
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# , along with transition to
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     BS VI
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  technology later in the year, prompting the industry body to forecast a modest growth of
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     3-5%
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERCENT</span>
# </mark>
#  in sales of passenger vehicles for
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     2019-20
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# . According to SIAM data, passenger vehicle sales in
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     the last fiscal
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  stood at
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     33,77,436
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  units, compared to
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     32,88,581
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  units in
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     2017-18
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# . The
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     2.7%
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERCENT</span>
# </mark>
#  growth follows the original forecast of
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     8-10%
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERCENT</span>
# </mark>
# , which was later revised to
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     6%
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERCENT</span>
# </mark>
# . This is the slowest pace of growth for the industry since
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     2013-14
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# , when sales declined
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.

# %% [markdown]
# ## Perfroming NER to find Named Entities in a corpus. Results are narrowed down to Persons, Organizations and GeoPolitical Entities only.

# %%
def getNE(text):
    ne = {}
    for x in nlp(text).ents:
        entity, label = x.text.strip(), x.label_
        if(label in ['GPE', 'PERSON', 'ORG'] and len(entity) > 1 and entity.lower() not in stoplist):
            ne[entity] = label
    return ne

# %%
getNE(corpus)
# Out:
# {'PV': 'GPE',
#  'Society of Indian Automobile Manufacturers': 'ORG',
#  'BS VI': 'ORG',
#  'Rajan Wadhera': 'PERSON',
#  'Wadhera': 'PERSON',
#  'GST': 'ORG',
#  'Samsung': 'ORG',
#  'India': 'GPE',
#  'Raju Pullan': 'PERSON',
#  'Pullan': 'PERSON',
#  'CRT': 'ORG',
#  'AI': 'ORG',
#  'IoT': 'GPE',
#  'Netherlands': 'GPE',
#  'Hak': 'PERSON',
#  'NL': 'ORG',
#  'Reliance Gas Transportation Infrastructure Ltd.': 'ORG',
#  'RTGIL': 'ORG',
#  'East West Pipeline Ltd.': 'ORG',
#  'EWPL': 'ORG',
#  'Singapore': 'GPE',
#  'Biometrix Marketing Limited': 'ORG',
#  'Biometrix': 'PERSON',
#  'RIL': 'ORG',
#  'Jamnagar': 'PERSON',
#  'Mukesh Ambani': 'PERSON',
#  'East West Pipeline': 'GPE',
#  'Brookfield': 'PERSON',
#  'India Infrastructure Trust': 'ORG',
#  '₹13,000': 'PERSON',
#  'The East West Pipeline Project': 'ORG',
#  'China': 'GPE',
#  'Russia': 'GPE',
#  'Project': 'ORG',
#  'Liquefied Natural Gas': 'ORG',
#  'LNG': 'ORG',
#  'India Ratings and Research': 'ORG',
#  'Ind-Ra': 'PERSON',
#  'the Ministry of Petroleum and Natural Gas': 'ORG',
#  'ONGC': 'ORG',
#  'the Association of Mutual Funds': 'ORG',
#  '₹11,756': 'GPE',
#  '₹23.80': 'GPE',
#  'N.S. Venkatesh': 'PERSON',
#  'AMFI': 'ORG',
#  'Venkatesh': 'PERSON',
#  'the Reserve Bank of India': 'ORG',
#  '₹84,638': 'ORG',
#  '₹67,190': 'GPE',
#  'SIP': 'ORG',
#  'AUM': 'ORG',
#  '₹51,343': 'PERSON',
#  '₹24,509 crore': 'ORG',
#  'U.S.': 'GPE',
#  'the Interbank Foreign Exchange': 'ORG',
#  '’s': 'ORG',
#  'Rupee': 'ORG',
#  'V.K. Sharma': 'PERSON',
#  'PCG & Capital Markets Strategy': 'ORG',
#  'HDFC Securities': 'ORG',
#  'Libya': 'GPE',
#  'Sharma': 'PERSON',
#  'MPC': 'ORG',
#  'INR': 'ORG',
#  'Rajesh Cheruvu': 'PERSON',
#  'WGC Wealth': 'ORG',
#  'Sensex': 'ORG',
#  'Nifty': 'PERSON',
#  'BSE': 'ORG',
#  '38,700.53': 'ORG',
#  'NSE Nifty': 'ORG',
#  'Financial Benchmark India Private Ltd.': 'ORG',
#  '₹33,215': 'ORG',
#  'the All India Sarafa Association': 'ORG',
#  'New York': 'GPE',
#  '₹33,045': 'ORG',
#  '₹32,790': 'ORG',
#  '₹26,400': 'GPE',
#  '11,604.50': 'ORG',
#  'Bank': 'ORG',
#  'Bajaj Finance': 'ORG',
#  'Vedanta': 'GPE',
#  'Tata Motors': 'ORG',
#  'Reliance Industries': 'ORG',
#  'SBI': 'ORG',
#  'Infosys': 'ORG',
#  'Mahindra': 'GPE',
#  'TCS': 'ORG',
#  'PowerGrid': 'ORG',
#  'NTPC': 'ORG',
#  'NSE': 'ORG',
#  '11,704.35': 'GPE',
#  'Teck': 'ORG',
#  'US': 'GPE',
#  'Brexit': 'GPE',
#  'Head of Research, Geojit Financial Services': 'ORG',
#  'Lok Sabha': 'PERSON',
#  'BSE Sensex': 'ORG',
#  '38,862.23': 'ORG',
#  'South Korea’s': 'GPE',
#  'KOSPI': 'ORG',
#  'Hong Kong’s': 'GPE',
#  'Hang Seng': 'ORG',
#  'Japan': 'GPE',
#  'Shanghai': 'GPE',
#  'State Bank of India': 'ORG',
#  'Jet Airways': 'ORG',
#  'SBI Capital Markets': 'ORG',
#  'Jet Airways’ Board': 'ORG',
#  'Naresh Goyal': 'ORG',
#  'Anita Goyal': 'PERSON',
#  'Board': 'ORG',
#  'EOI': 'ORG',
#  'Carlos Ghosn Nissan': 'PERSON',
#  'Carlos Ghosn': 'PERSON',
#  'Tokyo': 'GPE',
#  'Nissan': 'ORG',
#  'Ghosn': 'PERSON',
#  'Hiroto Saikawa': 'PERSON',
#  'Nissan Motor Co.': 'ORG',
#  'Renault SA’s': 'ORG',
#  'Jean-Dominique Senard': 'PERSON',
#  'Renault': 'ORG',
#  'Greg Kelly': 'PERSON',
#  'Saikawa': 'ORG',
#  'Ken Miyamoto': 'PERSON',
#  'Oman': 'GPE',
#  'Leaf': 'ORG',
#  'Infiniti': 'ORG',
#  'Mitsubishi Motors': 'ORG',
#  'Volkswagen AG': 'ORG',
#  'Germany': 'GPE',
#  'Toyota Motor Corp.': 'ORG',
#  'C. Venkatachalapathy': 'PERSON',
#  '39,013.22': 'ORG',
#  'Washington': 'GPE',
#  'Beijing': 'GPE',
#  'BPEA': 'ORG',
#  'NIIT Technologies Limited': 'ORG',
#  'NIIT Limited': 'ORG',
#  'NIIT Technologies': 'ORG',
#  'Rajendra Pawar': 'PERSON',
#  'Baring Private Equity Asia': 'GPE',
#  'Sudhir Singh': 'PERSON',
#  'Vijay Thadani': 'PERSON',
#  'BPEA’s': 'ORG',
#  'No.1 IT Training Company': 'ORG',
#  'Credit Suisse': 'ORG',
#  'Shardul Amarchand Mangaldas & Co': 'ORG',
#  'J. Sagar Associates': 'ORG',
#  'Ropes & Gray': 'ORG',
#  'Jimmy Mahtani': 'PERSON',
#  'WHISHWORKS IT Consulting': 'ORG',
#  'NIIT': 'ORG',
#  'Mukesh Kumar Jain': 'PERSON',
#  'MD': 'GPE',
#  'Oriental Bank of Commerce': 'ORG',
#  'OBC': 'ORG',
#  'RBI': 'ORG',
#  'PCA': 'ORG',
#  'AAA': 'ORG',
#  'AA': 'ORG',
#  'NPA': 'ORG',
#  'the National Company Law Tribunal': 'ORG',
#  'NCLT': 'ORG',
#  'CASA': 'ORG',
#  'RAM': 'ORG',
#  'Bhusan Power and Steel': 'ORG',
#  '₹1,616': 'GPE',
#  '₹51,673': 'PERSON',
#  'NBFC': 'ORG',
#  'Gaurav Anand': 'PERSON',
#  'Namaste Credit': 'ORG',
#  'Lucas Bianchi': 'PERSON',
#  'Sanjay Sharma': 'PERSON',
#  'Aye Finance': 'PERSON',
#  'Sanjay Kao': 'PERSON',
#  'Ujjivan Small Finance Bank': 'ORG',
#  'Kao': 'PERSON',
#  'MFI': 'ORG',
#  'Ujjivan': 'GPE',
#  'Q2': 'GPE',
#  'Tiruppur': 'ORG',
#  'Raja M. Shanmugham': 'PERSON',
#  'Tiruppur Exporters’ Association': 'ORG',
#  'TEA': 'ORG',
#  'A. Sakthivel': 'PERSON',
#  'Apparel Export Promotion Council': 'ORG',
#  'AEPC': 'ORG',
#  'GSP': 'ORG',
#  'Bangladesh': 'GPE',
#  'S.K. Kathiresh': 'PERSON',
#  'Carona Knitwear': 'ORG',
#  'Vietnam': 'GPE',
#  'Cambodia': 'GPE',
#  'Shanmugham': 'PERSON',
#  'Sakthivel': 'PERSON',
#  'U.K.': 'GPE',
#  'Chile': 'GPE',
#  'Israel': 'GPE',
#  'Drip Capital': 'ORG',
#  'The Apparel Export Promotion Council': 'ORG',
#  'Kathiresh': 'PERSON',
#  'EU': 'ORG',
#  'Gold Futures': 'ORG',
#  'Comex': 'ORG',
#  'the Multi Commodity Exchange of India': 'ORG',
#  'MCX': 'ORG',
#  '₹31,734': 'ORG',
#  '₹37,761': 'ORG',
#  'The U.S. Federal Reserve’s': 'ORG',
#  '₹32,000': 'ORG',
#  '₹31,542': 'ORG',
#  '₹32,280': 'GPE',
#  'Chennai': 'GPE',
#  'NCD': 'ORG',
#  'Shriram City Union': 'ORG',
#  'Magma Fincorp —': 'ORG',
#  'L&T Finance': 'ORG',
#  'L&T Finance’s': 'ORG',
#  'ICRA': 'ORG',
#  '₹10,000': 'ORG',
#  'Shriram City Union’s': 'ORG',
#  'AA+ (Care)': 'ORG',
#  'Crisil': 'ORG',
#  'Magma Fincorp': 'PERSON',
#  'Brickworks': 'PERSON',
#  'Acuite': 'PERSON',
#  'LIC Housing Finance': 'ORG',
#  'PNB Housing Finance': 'ORG',
#  'M&M Financial Services': 'ORG',
#  'Fincare': 'PERSON',
#  'Jana': 'PERSON',
#  'Stitch': 'ORG',
#  'Ayurveda': 'ORG',
#  'Unani': 'ORG',
#  'Homoeopathy': 'PERSON',
#  'the National Accreditation Board for Hospitals': 'ORG',
#  'Apollo Munich Maxima Health': 'ORG',
#  'ICICI Prudential Health Saver': 'ORG',
#  'Bajaj Allianz Tax Gain Plan': 'ORG',
#  '₹1.5': 'PERSON',
#  'Mumbai': 'GPE',
#  'EoI': 'ORG',
#  'Tatas Jet Airways': 'ORG',
#  'Tatas Accordingly': 'ORG',
#  'Jet Airways’': 'ORG',
#  'Read\n\n\n\n\n\nRevival': 'PERSON',
#  'Jet Airways Revival': 'ORG',
#  'the Checkpoint Tipline': 'ORG',
#  'WhatsApp': 'ORG',
#  'Facebook': 'PERSON',
#  'Hindi': 'GPE',
#  'Telugu': 'GPE',
#  'Bengali': 'GPE',
#  'Malayalam': 'GPE',
#  'IT Services Company': 'ORG',
#  'Competition Commission of India Vijay Thadani': 'ORG',
#  'MuleSoft': 'ORG',
#  'Big Data': 'ORG',
#  'Esri India Technologies Ltd': 'ORG',
#  'Environmental Systems Research Institute': 'ORG',
#  'Inc (Esri, Inc': 'ORG',
#  'Esri India Technologies': 'ORG',
#  'Geographic Information System': 'ORG',
#  'GIS': 'ORG',
#  'Esri,': 'ORG',
#  'NIIT Ltd': 'ORG',
#  '₹95.45': 'ORG',
#  'Boeing Co': 'ORG',
#  'Boeing': 'ORG',
#  'Ethiopian Airlines': 'ORG',
#  'Ethiopia': 'GPE',
#  'Lion Air': 'ORG',
#  'Indonesia': 'GPE',
#  'Dennis Muilenburg': 'PERSON',
#  'Muilenburg': 'PERSON',
#  'Spirit Aerosystems Holdings': 'ORG',
#  'National Transportation Safety Board': 'ORG',
#  'NTSB': 'ORG',
#  'Robert Sumwalt': 'PERSON',
#  'France': 'GPE',
#  'AP': 'ORG',
#  'Paris': 'GPE',
#  'Carole Ghosn': 'PERSON',
#  'the Financial Times': 'ORG',
#  'NHK': 'ORG',
#  'Junichiro Hironaka': 'PERSON',
#  '’m': 'PERSON',
#  'The Reserve Bank of India': 'ORG',
#  'Lakshmi Vilas Bank': 'ORG',
#  'LVB': 'ORG',
#  'Indiabulls Housing Finance': 'ORG',
#  'Additional Directors': 'ORG',
#  'the Additional Directors': 'ORG',
#  'The National Consumer Disputes Redressal Commission': 'ORG',
#  'Mridul Jain': 'PERSON',
#  '₹6,400': 'ORG',
#  'Lifestyle': 'ORG',
#  'Dubai': 'GPE',
#  'The Landmark Group': 'ORG',
#  'Vasanth Kumar': 'PERSON',
#  'Lifestyle International Pvt.': 'ORG',
#  'Guwahati': 'ORG',
#  'Ginger': 'PERSON',
#  'Code, Jack & Jones': 'ORG',
#  'Van Heusen': 'PERSON',
#  'Pepe Jeans': 'GPE',
#  'Bossini': 'GPE',
#  'Kumar': 'PERSON',
#  'Castrol': 'ORG',
#  'Turkey': 'GPE',
#  'Saudi Arabia': 'GPE',
#  'Omer Dormen': 'PERSON',
#  'Dormen': 'PERSON',
#  'EVs': 'PERSON',
#  'Nielsen': 'ORG',
#  'Mercedes-Benz': 'ORG',
#  'Mercedes Benz': 'ORG',
#  'EQC': 'ORG',
#  'Mercedes-Benz India': 'ORG',
#  'Martin Schwenk': 'PERSON',
#  'Mckinsey & Company': 'ORG',
#  'the Union Power Ministry': 'ORG',
#  'States': 'GPE',
#  'Centre': 'ORG',
#  'Discoms': 'ORG',
#  'the Central Electricity Authority': 'ORG',
#  'Mercedes': 'ORG',
#  'Smart': 'ORG',
#  'David Malpass': 'PERSON',
#  'File\n\xa0 | Photo Credit': 'ORG',
#  'U.S. Treasury': 'ORG',
#  'Trump': 'ORG',
#  'the World Bank': 'ORG',
#  'The World Bank’s': 'ORG',
#  'Malpass': 'PERSON',
#  'Treasury': 'ORG',
#  'International Affairs': 'ORG',
#  'Donald Trump': 'PERSON',
#  'Jim Yong-kim': 'PERSON',
#  'Kristalina Georgieva': 'PERSON',
#  'The World Bank': 'ORG',
#  'Chair of Boards of Directors of the International Bank for Reconstruction and Development': 'ORG',
#  'IBRD': 'ORG',
#  'International Development Association': 'ORG',
#  'IDA': 'ORG',
#  'Chair of Boards of Directors of the International Finance Corporation': 'ORG',
#  'IFC': 'ORG',
#  'Multilateral Investment Guarantee Agency': 'ORG',
#  'MIGA': 'ORG',
#  'the Administrative Council of the International Centre for Settlement of Investment Disputes': 'ORG',
#  'ICSID': 'ORG',
#  'Finance Ministerial': 'PERSON',
#  'World Bank-IMF Spring': 'ORG',
#  'Annual Meetings': 'ORG',
#  'the Financial Stability Board': 'ORG',
#  'the Organisation for Economic Cooperation and Development': 'ORG',
#  'the Overseas Private Investment Corporation': 'ORG',
#  'World Bank Group': 'ORG',
#  'the Debt Transparency Initiative': 'ORG',
#  'IMF': 'ORG',
#  'New York City': 'GPE',
#  'the Treasury for Developing Nations': 'ORG',
#  'State': 'ORG',
#  'the United States': 'GPE',
#  'the Council of the Americas, Economic Club of New York': 'ORG',
#  'the National Committee on U.S.—China Relations': 'ORG',
#  'Colorado College': 'ORG',
#  'the University of Denver': 'ORG',
#  'the School of Foreign Service': 'ORG',
#  'Georgetown University': 'ORG',
#  'Gagan Banga': 'ORG',
#  'Indiabulls Housing': 'ORG',
#  '₹18,000': 'PERSON',
#  'SLR': 'ORG',
#  '₹17,000': 'ORG',
#  'CRR': 'ORG',
#  '₹27,512': 'GPE',
#  'Indiabulls HFC': 'ORG',
#  'RBI’s': 'ORG',
#  'HFC': 'ORG',
#  'RoE': 'ORG',
#  'Essar Steel’s': 'ORG',
#  'CoC': 'ORG',
#  'ArcelorMittal': 'ORG',
#  'IDBI Bank': 'ORG',
#  'ICICI': 'ORG',
#  'Edelweiss Asset Reconstruction Company —': 'ORG',
#  'the National Company Law Appellate Tribunal': 'ORG',
#  'NCLAT': 'ORG',
#  'Standard Chartered Bank': 'ORG',
#  'SCB': 'ORG',
#  'the Supreme Court': 'ORG',
#  'Essar Steel': 'ORG',
#  'Tatas': 'GPE',
#  'the State Bank of India': 'ORG',
#  'Tata Sons': 'ORG',
#  'Tata Group': 'ORG',
#  'N. Chandrasekaran': 'PERSON',
#  'Jet’s': 'PERSON',
#  'Goyal': 'PERSON',
#  'Jet': 'PERSON',
#  'Ansuman Deb': 'PERSON',
#  'ICICI Securities': 'ORG',
#  'Singapore Airlines': 'ORG',
#  'Tata SIA Airlines': 'ORG',
#  'Vistara': 'GPE',
#  'IndiGo': 'ORG',
#  'Air India': 'ORG',
#  'SpiceJet': 'ORG',
#  'GoAir': 'ORG',
#  'Dena Bank': 'ORG',
#  'Vijaya Bank': 'ORG',
#  'Bank of Baroda': 'ORG',
#  'Rajesh Malhotra': 'ORG',
#  'MCLR': 'ORG',
#  'Malhotra': 'PERSON',
#  'Gujarat': 'GPE',
#  'Maharashtra': 'ORG',
#  'Karnataka': 'GPE',
#  'Rajasthan': 'PERSON',
#  'Uttar Pradesh': 'ORG',
#  'Tamil Nadu': 'ORG',
#  'Andhra Pradesh': 'PERSON',
#  'IBHF': 'ORG',
#  'Indiabulls': 'ORG',
#  'Sameer Gehlaut’s': 'PERSON',
#  'Gehlaut': 'PERSON',
#  'Parthasarathi Mukherjee': 'PERSON',
#  'MD&CEO': 'PERSON',
#  'Indiabulls Lakshmi Vilas Bank': 'ORG',
#  'S.S. Mundra': 'PERSON',
#  'IBH': 'ORG',
#  'Mukherjee': 'PERSON',
#  'Sameer Kalra': 'PERSON',
#  'Target Investing': 'ORG',
#  'Siva Shelters': 'PERSON',
#  'Constructions Private Ltd.': 'ORG',
#  'IL&FS Financial Services': 'ORG',
#  'C. Sivasankaran': 'PERSON',
#  'Siva Group': 'ORG',
#  'Hi-Tech Housing Projects Private Ltd.': 'ORG',
#  'Hyderabad': 'GPE',
#  'IFIN': 'ORG',
#  'Hitech Housing': 'ORG',
#  'Sivasankaran': 'PERSON',
#  'Bahrain': 'GPE',
#  'the Tata Group': 'ORG',
#  'BMIC': 'ORG',
#  'Malvinder': 'PERSON',
#  'Shivinder': 'PERSON',
#  'The Supreme Court': 'ORG',
#  'Ranbaxy': 'GPE',
#  'Malvinder Singh': 'PERSON',
#  'Shivinder Singh': 'PERSON',
#  'Bench': 'ORG',
#  'Ranjan Gogoi': 'PERSON',
#  'Singh': 'ORG',
#  'Daiichi Sankyo': 'ORG',
#  'CJI': 'ORG',
#  'Fortis': 'ORG',
#  'Religare': 'ORG',
#  'Kapil Sibal': 'PERSON',
#  'Sibal': 'PERSON',
#  'New Delhi’s Indira Gandhi International Airport': 'ORG',
#  'IGI': 'ORG',
#  'the Indian Oil Corporation': 'ORG',
#  'Britannia Industries Ltd.': 'ORG',
#  'BIL': 'ORG',
#  'Kapre': 'PERSON',
#  'Treat Croissant': 'ORG',
#  'Chipita': 'ORG',
#  'BIL’s': 'ORG',
#  'Mr Kapre': 'PERSON',
#  'Bengaluru': 'GPE',
#  'Ranjangaon': 'GPE',
#  '₹24.51': 'GPE',
#  '₹24,500': 'ORG',
#  '₹11.08': 'GPE',
#  'MTM': 'ORG',
#  'ELSS': 'ORG',
#  '₹23,400': 'PERSON',
#  'HDFC Mutual Fund': 'ORG',
#  'ICICI Prudential Mutual Fund': 'ORG',
#  'SBI Mutual Fund': 'ORG',
#  'Vikram Kirloskar': 'PERSON',
#  'Toyota': 'ORG',
#  'Kirloskar Motor': 'PERSON',
#  'the Confederation of Indian Industry': 'ORG',
#  'Kirloskar': 'ORG',
#  'Kirloskar Systems Ltd': 'ORG',
#  'Toyota Kirloskar Motor': 'ORG',
#  'Bharti Enterprises': 'ORG',
#  'Uday Kotak': 'PERSON',
#  'MD & CEO': 'ORG',
#  'Kotak Mahindra Bank': 'ORG',
#  'T.V. Narendran': 'PERSON',
#  'CII': 'ORG',
#  'Global Innovation and Technology Alliance Board': 'ORG',
#  'Indian Oil Corporation': 'ORG',
#  'IOC': 'ORG',
#  'PTI': 'ORG',
#  'Read\n\n\n\n\n\nJet Airways’': 'PERSON',
#  'State Bank': 'ORG',
#  'Neuberg Diagnostics': 'PERSON',
#  'GSK': 'ORG',
#  'Velu': 'PERSON',
#  'Neuburg Diagnostics': 'ORG',
#  'South Africa': 'GPE',
#  'Kenya': 'GPE',
#  'Tanzania': 'GPE',
#  'Uganda': 'GPE',
#  'Nigeria': 'GPE',
#  'Ghana': 'GPE',
#  'Mozambique': 'ORG',
#  'Neuburg': 'GPE',
#  'Pune': 'GPE',
#  'Rahul Sharma': 'PERSON',
#  'Micromax': 'ORG',
#  'Artificial Intelligence (': 'ORG',
#  'Jet Airways (India) Ltd.': 'ORG',
#  '” State Bank of India': 'ORG',
#  'Shaktikanta Das': 'PERSON',
#  'OMO': 'ORG',
#  'GMR': 'ORG',
#  'Hyderabad International Airport Ltd.': 'ORG',
#  'GMR Airports Ltd.': 'ORG',
#  'GMR Infrastructure Ltd.': 'ORG',
#  'the Rajiv Gandhi International Airport': 'ORG',
#  'Grandhi Kiran Kumar': 'PERSON',
#  'GHIAL': 'ORG',
#  'Das': 'PERSON',
#  'the Hon’ble Supreme Court’s': 'ORG',
#  'Solidaridad': 'GPE',
#  'Digital': 'ORG',
#  'Assam': 'GPE',
#  'West Bengal': 'GPE',
#  'Shatadru Chattopadhayay': 'GPE',
#  'Solidaridad Asia': 'ORG',
#  'Trinitea': 'ORG',
#  'Indian Tea Association': 'ORG',
#  'the Indian Tea Association': 'ORG',
#  'Association of Small': 'ORG',
#  'the United Planters Association of Southern India': 'ORG',
#  'UPASI': 'ORG',
#  '” Tea Board': 'ORG',
#  'P. K. Bezboruah': 'PERSON',
#  'ITA': 'ORG',
#  'Vivek Goenka': 'PERSON',
#  'Traceability': 'ORG',
#  'Groupe PSA': 'ORG',
#  'Hosur': 'ORG',
#  'Thomas Delepoulle': 'PERSON',
#  'Groupe PSA’s': 'ORG',
#  'Michelle Wen': 'PERSON',
#  'GPSQ': 'ORG',
#  'CK Birla Group': 'ORG',
#  'Tiruvallur': 'GPE',
#  'AVTEC Ltd. Tata': 'ORG',
#  'Tanishq': 'ORG',
#  'Sandeep Kulhalli': 'PERSON',
#  'Titan Company Ltd.': 'ORG',
#  '& C': 'ORG',
#  'Kannada': 'PERSON',
#  'Kulhalli': 'PERSON',
#  'Caratlane': 'ORG',
#  'S. Subramaniam': 'PERSON',
#  'CFO': 'ORG'}

# %% [markdown]
# ## Performing sentimental analysis for each entity detected in all the articles. The method also involves checking upto 3 sentences ahead if the entity is found in a sentence, to include the further sentences with pronouns for the same entity.

# %%
# loop through the sentences containing each NER can calculate the sentiment score and average it.
def getSentimentScore(term, corpus):
    sia = SentimentIntensityAnalyzer()
    scores = []
    sentences = sent_tokenize(corpus)
    weights = [1, 0.75, 0.5, 0.25]
    for i in range(len(sentences)):
        sentence = sentences[i]
        if term in sentence:
            scores.append(sia.polarity_scores(sentence)['compound'])
            x = i+1
            while(x < len(sentences) and x-i <= 3):
                if term in sentences[x]:
                    break
                for word, tag in pos_tag(word_tokenize(sentences[x])):
                    if tag in ['PRP', 'PRP$']:
                        scores.append(sia.polarity_scores(sentences[x])['compound'] * weights[x-i])
                        break
                x += 1

    avg_sent_score = round(sum(scores)/len(scores), 5) if len(scores)>0 else 0
    return avg_sent_score

# %%
# organising the enities and their scores in a dictionary on the base of entity types
nes = getNE(corpus)
sent_scores = {}
for ne in nes:
    ne_tag = nes[ne]
    if ne_tag not in sent_scores:
        sent_scores[ne_tag] = []
    sent_scores[ne_tag].append((ne, getSentimentScore(ne, corpus)))

# %%
# Sorting the entities in increasing order of sentiment score.
for ne_tag in sent_scores:
    sent_scores[ne_tag] = sorted(sent_scores[ne_tag], key=lambda x: x[1])

# %%
pprint(sent_scores)
# Out:
# {'GPE': [('Ranbaxy', -0.72515),
#          ('PV', -0.5994),
#          ('₹11.08', -0.5423),
#          ('Indonesia', -0.46625),
#          ('₹11,756', -0.3818),
#          ('Vedanta', -0.3818),
#          ('Libya', -0.3182),
#          ('Shanghai', -0.296),
#          ('₹24.51', -0.1806),
#          ('Ethiopia', -0.13786),
#          ('Germany', -0.13397),
#          ('Japan', -0.1081),
#          ('US', -0.10224),
#          ('Singapore', -0.08705),
#          ('Brexit', -0.07275),
#          ('China', -0.03807),
#          ('Paris', -0.00407),
#          ('₹67,190', 0.0),
#          ('₹26,400', 0.0),
#          ('₹32,280', 0.0),
#          ('Pepe Jeans', 0.0),
#          ('Bossini', 0.0),
#          ('Bahrain', 0.0),
#          ('Bengaluru', 0.0),
#          ('Ranjangaon', 0.0),
#          ('Kenya', 0.0),
#          ('Tanzania', 0.0),
#          ('Uganda', 0.0),
#          ('Nigeria', 0.0),
#          ('Ghana', 0.0),
#          ('Shatadru Chattopadhayay', 0.0),
#          ('Chennai', 0.00205),
#          ('Vistara', 0.0182),
#          ('Tokyo', 0.01962),
#          ('Dubai', 0.02573),
#          ('U.S.', 0.0645),
#          ('IoT', 0.09107),
#          ('Netherlands', 0.0911),
#          ('MD', 0.13131),
#          ('Solidaridad', 0.13648),
#          ('East West Pipeline', 0.14006),
#          ('States', 0.1465),
#          ('New York', 0.15886),
#          ('Pune', 0.1591),
#          ('India', 0.17286),
#          ('Neuburg', 0.1784),
#          ('Assam', 0.20617),
#          ('West Bengal', 0.20617),
#          ('Oman', 0.21075),
#          ('Vietnam', 0.2263),
#          ('Mumbai', 0.23774),
#          ('Russia', 0.2453),
#          ('Tatas', 0.24626),
#          ('France', 0.25383),
#          ('Tiruvallur', 0.26335),
#          ('Bangladesh', 0.26607),
#          ('Ujjivan', 0.26913),
#          ('₹1,616', 0.2787),
#          ('New York City', 0.28733),
#          ('Q2', 0.29843),
#          ('South Africa', 0.3182),
#          ('Turkey', 0.32707),
#          ('Saudi Arabia', 0.32707),
#          ('the United States', 0.32985),
#          ('Hyderabad', 0.37703),
#          ('Mahindra', 0.37747),
#          ('South Korea’s', 0.3818),
#          ('Hong Kong’s', 0.3818),
#          ('₹27,512', 0.3924),
#          ('Cambodia', 0.3991),
#          ('Washington', 0.4215),
#          ('Beijing', 0.4215),
#          ('₹23.80', 0.4588),
#          ('Gujarat', 0.46045),
#          ('Karnataka', 0.46045),
#          ('11,704.35', 0.49533),
#          ('Hindi', 0.5615),
#          ('Telugu', 0.5615),
#          ('Bengali', 0.5615),
#          ('Malayalam', 0.5615),
#          ('U.K.', 0.58315),
#          ('Chile', 0.58315),
#          ('Israel', 0.58315),
#          ('Baring Private Equity Asia', 0.69838)],
#  'ORG': [('The Supreme Court', -0.72515),
#          ('IOC', -0.6005),
#          ('Society of Indian Automobile Manufacturers', -0.5994),
#          ('₹24,500', -0.5423),
#          ('Lion Air', -0.46625),
#          ('Tata Motors', -0.3818),
#          ('₹37,761', -0.3182),
#          ('the Interbank Foreign Exchange', -0.317),
#          ('MTM', -0.2732),
#          ('38,700.53', -0.26213),
#          ('Gold Futures', -0.2315),
#          ('Mckinsey & Company', -0.2263),
#          ('New Delhi’s Indira Gandhi International Airport', -0.2263),
#          ('Daiichi Sankyo', -0.2142),
#          ('Saikawa', -0.20105),
#          ('₹24,509 crore', -0.20095),
#          ('Leaf', -0.20095),
#          ('Infiniti', -0.20095),
#          ('Mitsubishi Motors', -0.20095),
#          ('Volkswagen AG', -0.20095),
#          ('Toyota Motor Corp.', -0.20095),
#          ('Bajaj Finance', -0.1909),
#          ('Guwahati', -0.1909),
#          ('Crisil', -0.17723),
#          ('the Financial Times', -0.16463),
#          ('Bench', -0.16065),
#          ('PTI', -0.16035),
#          ('Comex', -0.15332),
#          ('the Debt Transparency Initiative', -0.14487),
#          ('11,604.50', -0.13487),
#          ('SpiceJet', -0.1256),
#          ('GoAir', -0.1256),
#          ('The Reserve Bank of India', -0.1215),
#          ('Jet Airways Revival', -0.106),
#          ('Shardul Amarchand Mangaldas & Co', -0.1027),
#          ('NHK', -0.10084),
#          ('Indian Oil Corporation', -0.09584),
#          ('Reliance Industries', -0.08913),
#          ('Toyota', -0.08038),
#          ('Biometrix Marketing Limited', -0.07543),
#          ('MCLR', -0.0741),
#          ('Mercedes-Benz India', -0.064),
#          ('Boeing Co', -0.0516),
#          ('Mercedes-Benz', -0.0512),
#          ('The National Consumer Disputes Redressal Commission', -0.04393),
#          ('Nissan', -0.04263),
#          ('Additional Directors', -0.03425),
#          ('Lifestyle', -0.03384),
#          ('Renault', -0.03045),
#          ('Ethiopian Airlines', -0.0284),
#          ('IFC', -0.0227),
#          ('World Bank-IMF Spring', -0.02167),
#          ('Annual Meetings', -0.02167),
#          ('the Financial Stability Board', -0.02167),
#          ('the Organisation for Economic Cooperation and Development',
#           -0.02167),
#          ('the Overseas Private Investment Corporation', -0.02167),
#          ('World Bank Group', -0.02167),
#          ('CJI', -0.0181),
#          ('IBRD', -0.01625),
#          ('The East West Pipeline Project', 0.0),
#          ('the Association of Mutual Funds', 0.0),
#          ('₹84,638', 0.0),
#          ('Financial Benchmark India Private Ltd.', 0.0),
#          ('₹32,790', 0.0),
#          ('SBI Capital Markets', 0.0),
#          ('39,013.22', 0.0),
#          ('the National Company Law Tribunal', 0.0),
#          ('Ujjivan Small Finance Bank', 0.0),
#          ('Carona Knitwear', 0.0),
#          ('EU', 0.0),
#          ('₹31,734', 0.0),
#          ('₹31,542', 0.0),
#          ('Magma Fincorp —', 0.0),
#          ('LIC Housing Finance', 0.0),
#          ('PNB Housing Finance', 0.0),
#          ('M&M Financial Services', 0.0),
#          ('Tatas Jet Airways', 0.0),
#          ('Tatas Accordingly', 0.0),
#          ('Lifestyle International Pvt.', 0.0),
#          ('Code, Jack & Jones', 0.0),
#          ('Mercedes Benz', 0.0),
#          ('EQC', 0.0),
#          ('Chair of Boards of Directors of the International Bank for '
#           'Reconstruction and Development',
#           0.0),
#          ('International Development Association', 0.0),
#          ('IDA', 0.0),
#          ('the National Company Law Appellate Tribunal', 0.0),
#          ('Singapore Airlines', 0.0),
#          ('Tata SIA Airlines', 0.0),
#          ('Indiabulls Lakshmi Vilas Bank', 0.0),
#          ('Constructions Private Ltd.', 0.0),
#          ('Siva Group', 0.0),
#          ('the Tata Group', 0.0),
#          ('BMIC', 0.0),
#          ('Kirloskar Systems Ltd', 0.0),
#          ('Toyota Kirloskar Motor', 0.0),
#          ('Bharti Enterprises', 0.0),
#          ('Mozambique', 0.0),
#          ('Digital', 0.0),
#          ('NPA', 0.00393),
#          ('WhatsApp', 0.00404),
#          ('RIL', 0.01726),
#          ('NCLAT', 0.02137),
#          ('NCLT', 0.02396),
#          ('Mercedes', 0.02432),
#          ('The Landmark Group', 0.02573),
#          ('IMF', 0.02746),
#          ('the Checkpoint Tipline', 0.0326),
#          ('Indiabulls HFC', 0.0359),
#          ('RAM', 0.0386),
#          ('GSK', 0.0386),
#          ('Traceability', 0.0386),
#          ('SCB', 0.04495),
#          ('SBI', 0.04768),
#          ('Shriram City Union', 0.05135),
#          ('Apollo Munich Maxima Health', 0.0516),
#          ('ICICI Prudential Health Saver', 0.0516),
#          ('Gagan Banga', 0.05464),
#          ('Vijaya Bank', 0.05737),
#          ('Bank of Baroda', 0.05737),
#          ('Rajesh Malhotra', 0.05737),
#          ('Standard Chartered Bank', 0.05993),
#          ('Jet Airways', 0.06076),
#          ('J. Sagar Associates', 0.064),
#          ('Ropes & Gray', 0.064),
#          ('RoE', 0.06687),
#          ('Neuburg Diagnostics', 0.0772),
#          ('Tata Sons', 0.07853),
#          ('the Council of the Americas, Economic Club of New York', 0.08333),
#          ('the National Committee on U.S.—China Relations', 0.08333),
#          ('Rupee', 0.0858),
#          ('ITA', 0.09107),
#          ('Jet Airways’', 0.09154),
#          ('MPC', 0.09724),
#          ('Air India', 0.09783),
#          ('Nielsen', 0.09867),
#          ('ICICI Securities', 0.09867),
#          ('BIL', 0.10032),
#          ('Tata Group', 0.10159),
#          ('Shriram City Union’s', 0.1027),
#          ('AA+ (Care)', 0.1027),
#          ('Hosur', 0.10534),
#          ('Trinitea', 0.10537),
#          ('EOI', 0.10607),
#          ('Renault SA’s', 0.1096),
#          ('Dena Bank', 0.11078),
#          ('Boeing', 0.11135),
#          ('L&T Finance', 0.11265),
#          ('HFC', 0.11414),
#          ('IBHF', 0.11576),
#          ('AAA', 0.11988),
#          ('₹6,400', 0.125),
#          ('Colorado College', 0.125),
#          ('the University of Denver', 0.125),
#          ('the School of Foreign Service', 0.125),
#          ('Georgetown University', 0.125),
#          ('& C', 0.13031),
#          ('OMO', 0.13558),
#          ('Ayurveda', 0.1358),
#          ('Unani', 0.1358),
#          ('the National Accreditation Board for Hospitals', 0.1358),
#          ('CK Birla Group', 0.1366),
#          ('Singh', 0.13783),
#          ('IL&FS Financial Services', 0.13899),
#          ('Apparel Export Promotion Council', 0.1421),
#          ('the World Bank', 0.14367),
#          ('LVB', 0.15175),
#          ('ICICI', 0.15185),
#          ('Kirloskar', 0.15272),
#          ('CII', 0.15272),
#          ('Indiabulls', 0.15327),
#          ('Lakshmi Vilas Bank', 0.15506),
#          ('AP', 0.15618),
#          ('Solidaridad Asia', 0.16063),
#          ('AUM', 0.16065),
#          ('38,862.23', 0.16277),
#          ('IBH', 0.16295),
#          ('’s', 0.16449),
#          ('ELSS', 0.16463),
#          ('IndiGo', 0.1675),
#          ('Groupe PSA', 0.16881),
#          ('Indiabulls Housing Finance', 0.17057),
#          ('SLR', 0.17083),
#          ('CRR', 0.17083),
#          ('Bank', 0.1721),
#          ('Jet Airways’ Board', 0.1752),
#          ('Britannia Industries Ltd.', 0.17663),
#          ('AMFI', 0.17668),
#          ('Nissan Motor Co.', 0.18137),
#          ('Indiabulls Housing', 0.18177),
#          ('BIL’s', 0.182),
#          ('State', 0.18254),
#          ('the Union Power Ministry', 0.1829),
#          ('Samsung', 0.18462),
#          ('The World Bank', 0.1858),
#          ('AI', 0.19018),
#          ('IGI', 0.1909),
#          ('the Indian Oil Corporation', 0.1909),
#          ('the Confederation of Indian Industry', 0.1909),
#          ('MD & CEO', 0.1909),
#          ('Kotak Mahindra Bank', 0.1909),
#          ('GST', 0.1919),
#          ('WGC Wealth', 0.19425),
#          ('Tiruppur', 0.19431),
#          ('Bajaj Allianz Tax Gain Plan', 0.1957),
#          ('L&T Finance’s', 0.1998),
#          ('AA', 0.20049),
#          ('ArcelorMittal', 0.20157),
#          ('HDFC Mutual Fund', 0.2023),
#          ('ICICI Prudential Mutual Fund', 0.2023),
#          ('SBI Mutual Fund', 0.2023),
#          ('State Bank', 0.20838),
#          ('Board', 0.21071),
#          ('CoC', 0.21204),
#          ('Fortis', 0.21397),
#          ('Religare', 0.21397),
#          ('MCX', 0.2153),
#          ('RBI', 0.21936),
#          ('MFI', 0.22283),
#          ('₹17,000', 0.22777),
#          ('CRT', 0.2315),
#          ('EWPL', 0.23163),
#          ('Sensex', 0.23445),
#          ('NBFC', 0.23525),
#          ('Centre', 0.23891),
#          ('CASA', 0.2417),
#          ('Maharashtra', 0.24782),
#          ('Hitech Housing', 0.25),
#          ('NCD', 0.25702),
#          ('AEPC', 0.26053),
#          ('AVTEC Ltd. Tata', 0.26335),
#          ('SIP', 0.2652),
#          ('Chair of Boards of Directors of the International Finance '
#           'Corporation',
#           0.27305),
#          ('Multilateral Investment Guarantee Agency', 0.27305),
#          ('MIGA', 0.27305),
#          ('the Administrative Council of the International Centre for '
#           'Settlement of Investment Disputes',
#           0.27305),
#          ('ICSID', 0.27305),
#          ('the All India Sarafa Association', 0.2732),
#          ('Naresh Goyal', 0.2732),
#          ('₹32,000', 0.2732),
#          ('Bhusan Power and Steel', 0.2787),
#          ('The World Bank’s', 0.2787),
#          ('International Affairs', 0.2787),
#          ('Namaste Credit', 0.2802),
#          ('RBI’s', 0.29014),
#          ('Micromax', 0.29287),
#          ('Artificial Intelligence (', 0.29287),
#          ('BSE', 0.29559),
#          ('NSE', 0.29592),
#          ('PCG & Capital Markets Strategy', 0.296),
#          ('HDFC Securities', 0.296),
#          ('Spirit Aerosystems Holdings', 0.29847),
#          ('ICRA', 0.2997),
#          ('OBC', 0.30093),
#          ('₹33,215', 0.3066),
#          ('Indian Tea Association', 0.30925),
#          ('BS VI', 0.31127),
#          ('Castrol', 0.31265),
#          ('Treat Croissant', 0.31473),
#          ('Chipita', 0.31473),
#          ('Head of Research, Geojit Financial Services', 0.32135),
#          ('State Bank of India', 0.32246),
#          ('EoI', 0.32475),
#          ('Project', 0.3263),
#          ('Discoms', 0.33837),
#          ('Essar Steel', 0.3387),
#          ('Stitch', 0.33957),
#          ('₹33,045', 0.34),
#          ('₹10,000', 0.34),
#          ('NIIT', 0.34535),
#          ('NL', 0.35015),
#          ('Reliance Gas Transportation Infrastructure Ltd.', 0.35015),
#          ('RTGIL', 0.35015),
#          ('East West Pipeline Ltd.', 0.35015),
#          ('PCA', 0.3542),
#          ('Hyderabad International Airport Ltd.', 0.3548),
#          ('IDBI Bank', 0.3612),
#          ('Edelweiss Asset Reconstruction Company —', 0.3612),
#          ('LNG', 0.36573),
#          ('the Central Electricity Authority', 0.37095),
#          ('INR', 0.3738),
#          ('Teck', 0.3818),
#          ('KOSPI', 0.3818),
#          ('Hang Seng', 0.3818),
#          ('Global Innovation and Technology Alliance Board', 0.3818),
#          ('Groupe PSA’s', 0.3818),
#          ('GPSQ', 0.3818),
#          ('NSE Nifty', 0.3847),
#          ('Tanishq', 0.38787),
#          ('Drip Capital', 0.39225),
#          ('Esri India Technologies Ltd', 0.3943),
#          ('Environmental Systems Research Institute', 0.3943),
#          ('Inc (Esri, Inc', 0.3943),
#          ('Esri India Technologies', 0.3943),
#          ('Geographic Information System', 0.3943),
#          ('GIS', 0.3943),
#          ('Esri,', 0.3943),
#          ('NIIT Ltd', 0.3943),
#          ('₹95.45', 0.3943),
#          ('Target Investing', 0.3953),
#          ('BPEA', 0.40159),
#          ('Smart', 0.4019),
#          ('NIIT Technologies', 0.40374),
#          ('” Tea Board', 0.40775),
#          ('Treasury', 0.41126),
#          ('the Indian Tea Association', 0.41233),
#          ('Association of Small', 0.41233),
#          ('the United Planters Association of Southern India', 0.41233),
#          ('UPASI', 0.41233),
#          ('the State Bank of India', 0.4201),
#          ('Hi-Tech Housing Projects Private Ltd.', 0.4215),
#          ('the Treasury for Developing Nations', 0.431),
#          ('the Reserve Bank of India', 0.43299),
#          ('NIIT Limited', 0.44471),
#          ('the Supreme Court', 0.44727),
#          ('Liquefied Natural Gas', 0.4486),
#          ('India Ratings and Research', 0.4486),
#          ('The U.S. Federal Reserve’s', 0.4588),
#          ('IFIN', 0.4588),
#          ('Uttar Pradesh', 0.46045),
#          ('Tamil Nadu', 0.46045),
#          ('Trump', 0.4738),
#          ('Infosys', 0.47645),
#          ('TCS', 0.47645),
#          ('National Transportation Safety Board', 0.4774),
#          ('NTSB', 0.4774),
#          ('Titan Company Ltd.', 0.47777),
#          ('” State Bank of India', 0.482),
#          ('Oriental Bank of Commerce', 0.5313),
#          ('GMR', 0.54485),
#          ('Essar Steel’s', 0.5559),
#          ('The Apparel Export Promotion Council', 0.5574),
#          ('the Additional Directors', 0.5574),
#          ('Jet Airways (India) Ltd.', 0.5574),
#          ('Tiruppur Exporters’ Association', 0.5615),
#          ('TEA', 0.5615),
#          ('GSP', 0.57053),
#          ('the Multi Commodity Exchange of India', 0.5719),
#          ('Credit Suisse', 0.57395),
#          ('the Rajiv Gandhi International Airport', 0.596),
#          ('WHISHWORKS IT Consulting', 0.60933),
#          ('the Ministry of Petroleum and Natural Gas', 0.6124),
#          ('BSE Sensex', 0.6249),
#          ('File\n\xa0 | Photo Credit', 0.6369),
#          ('U.S. Treasury', 0.6369),
#          ('Caratlane', 0.6369),
#          ('CFO', 0.6369),
#          ('NIIT Technologies Limited', 0.6383),
#          ('IT Services Company', 0.6421),
#          ('India Infrastructure Trust', 0.6597),
#          ('MuleSoft', 0.66705),
#          ('Big Data', 0.66705),
#          ('ONGC', 0.66825),
#          ('Competition Commission of India Vijay Thadani', 0.6893),
#          ('GMR Airports Ltd.', 0.714),
#          ('GMR Infrastructure Ltd.', 0.714),
#          ('GHIAL', 0.7349),
#          ('PowerGrid', 0.7506),
#          ('NTPC', 0.7506),
#          ('the Hon’ble Supreme Court’s', 0.76155),
#          ('No.1 IT Training Company', 0.8702),
#          ('BPEA’s', 0.8885)],
#  'PERSON': [('Malvinder Singh', -0.72515),
#             ('Shivinder Singh', -0.72515),
#             ('Malvinder', -0.416),
#             ('Shivinder', -0.416),
#             ('Dennis Muilenburg', -0.3753),
#             ('Brickworks', -0.296),
#             ('Acuite', -0.296),
#             ('A. Sakthivel', -0.2732),
#             ('Ranjan Gogoi', -0.2142),
#             ('Greg Kelly', -0.2023),
#             ('₹51,343', -0.20095),
#             ('Lok Sabha', -0.1661),
#             ('Carole Ghosn', -0.16463),
#             ('’m', -0.15958),
#             ('Magma Fincorp', -0.148),
#             ('Read\n\n\n\n\n\nRevival', -0.106),
#             ('Junichiro Hironaka', -0.08333),
#             ('Biometrix', -0.07543),
#             ('Ghosn', -0.06804),
#             ('Martin Schwenk', -0.064),
#             ('Muilenburg', -0.05586),
#             ('Sanjay Sharma', -0.04685),
#             ('Aye Finance', -0.04685),
#             ('Read\n\n\n\n\n\nJet Airways’', -0.0429),
#             ('Finance Ministerial', -0.02167),
#             ('Facebook', -0.01332),
#             ('Mukesh Ambani', 0.0),
#             ('N.S. Venkatesh', 0),
#             ('V.K. Sharma', 0),
#             ('Sanjay Kao', 0.0),
#             ('S.K. Kathiresh', 0),
#             ('Vasanth Kumar', 0.0),
#             ('Ginger', 0.0),
#             ('Van Heusen', 0.0),
#             ('Parthasarathi Mukherjee', 0.0),
#             ('MD&CEO', 0.0),
#             ('C. Sivasankaran', 0.0),
#             ('Kapil Sibal', 0.0),
#             ('Sibal', 0.0),
#             ('Mr Kapre', 0.0),
#             ('Kirloskar Motor', 0.0),
#             ('T.V. Narendran', 0),
#             ('Thomas Delepoulle', 0.0),
#             ('Jet’s', 0.0111),
#             ('Fincare', 0.0258),
#             ('Jana', 0.0258),
#             ('C. Venkatachalapathy', 0.02675),
#             ('Neuberg Diagnostics', 0.0386),
#             ('Jet', 0.05224),
#             ('Sharma', 0.07231),
#             ('Sivasankaran', 0.09176),
#             ('Ansuman Deb', 0.09867),
#             ('Jean-Dominique Senard', 0.1096),
#             ('Goyal', 0.11091),
#             ('Kapre', 0.11141),
#             ('Sakthivel', 0.11213),
#             ('N. Chandrasekaran', 0.1178),
#             ('EVs', 0.11979),
#             ('Hiroto Saikawa', 0.1226),
#             ('Jamnagar', 0.125),
#             ('Mridul Jain', 0.125),
#             ('₹51,673', 0.12727),
#             ('Vikram Kirloskar', 0.12727),
#             ('Homoeopathy', 0.1358),
#             ('Vivek Goenka', 0.1366),
#             ('Velu', 0.13944),
#             ('Carlos Ghosn', 0.14828),
#             ('Wadhera', 0.15157),
#             ('₹18,000', 0.1585),
#             ('₹1.5', 0.16463),
#             ('Malpass', 0.17204),
#             ('Gaurav Anand', 0.1783),
#             ('Raju Pullan', 0.1902),
#             ('Uday Kotak', 0.1909),
#             ('Kao', 0.19369),
#             ('Rajesh Cheruvu', 0.19425),
#             ('Venkatesh', 0.2034),
#             ('Kristalina Georgieva', 0.21075),
#             ('Siva Shelters', 0.21202),
#             ('Pullan', 0.21498),
#             ('Malhotra', 0.2186),
#             ('Jimmy Mahtani', 0.2202),
#             ('Kathiresh', 0.23835),
#             ('Sameer Gehlaut’s', 0.23835),
#             ('Gehlaut', 0.23835),
#             ('₹23,400', 0.24695),
#             ('Shaktikanta Das', 0.24962),
#             ('Anita Goyal', 0.2732),
#             ('Mukherjee', 0.2749),
#             ('Kumar', 0.28138),
#             ('Rahul Sharma', 0.29287),
#             ('Rajan Wadhera', 0.30077),
#             ('Ken Miyamoto', 0.3073),
#             ('David Malpass', 0.31845),
#             ('Omer Dormen', 0.32707),
#             ('Dormen', 0.32707),
#             ('Kannada', 0.34627),
#             ('Shanmugham', 0.3524),
#             ('Kulhalli', 0.35833),
#             ('S.S. Mundra', 0.3753),
#             ('Nifty', 0.37693),
#             ('Michelle Wen', 0.3818),
#             ('Donald Trump', 0.39225),
#             ('Jim Yong-kim', 0.39225),
#             ('Sameer Kalra', 0.3953),
#             ('Sandeep Kulhalli', 0.3982),
#             ('P. K. Bezboruah', 0.40775),
#             ('Hak', 0.41923),
#             ('Das', 0.42106),
#             ('Carlos Ghosn Nissan', 0.4215),
#             ('Rajasthan', 0.46045),
#             ('Andhra Pradesh', 0.46045),
#             ('Robert Sumwalt', 0.4774),
#             ('Ind-Ra', 0.5305),
#             ('Mukesh Kumar Jain', 0.5313),
#             ('Raja M. Shanmugham', 0.5615),
#             ('Lucas Bianchi', 0.5859),
#             ('S. Subramaniam', 0.6369),
#             ('Rajendra Pawar', 0.65125),
#             ('Brookfield', 0.6597),
#             ('₹13,000', 0.6597),
#             ('Grandhi Kiran Kumar', 0.7349),
#             ('Sudhir Singh', 0.7557),
#             ('Vijay Thadani', 0.7557)]}

# %%
print('Total NE detected:')
for ne_tag in sent_scores:
    print('{}: {}'.format(ne_tag, len(sent_scores[ne_tag])))
# Out:
# Total NE detected:
# GPE: 84
# ORG: 361
# PERSON: 124

# %% [markdown]
# ## Plotting the top and bottom N entities on the basis of sentiment score rankings.

# %%
def plotSentScores(data, n, features):
    if n>0:
        df = pd.DataFrame(data[-n:], columns=features)
        sb.barplot(data=df, y=features[0], x=features[1], orient='h', color='green')
    elif(n<0):
        df = pd.DataFrame(data[:abs(n)], columns=features)
        sb.barplot(data=df, y=features[0], x=features[1], orient='h', color='red')

# %%
plotSentScores(sent_scores['PERSON'], -30, ['Entity (Person)', 'Average Sentiment Score'])

# %%
plotSentScores(sent_scores['PERSON'], 30, ['Entity (Person)', 'Average Sentiment Score'])

# %%
plotSentScores(sent_scores['GPE'], -30, ['Entity (Geo-Political)', 'Average Sentiment Score'])

# %%
plotSentScores(sent_scores['GPE'], 30, ['Entity (Geo-Political)', 'Average Sentiment Score'])

# %%
plotSentScores(sent_scores['ORG'], -30, ['Entity (Organisation)', 'Average Sentiment Score'])

# %%
plotSentScores(sent_scores['ORG'], 30, ['Entity (Organisation)', 'Average Sentiment Score'])
